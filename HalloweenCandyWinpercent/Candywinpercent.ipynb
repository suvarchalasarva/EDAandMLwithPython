# %% [markdown]
# <img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240"
# height="360" />
# ### Exploratory Data Analysis and Machine Learning - Predicting Halloween Candy Brand Winpercent DataSet

# %% [markdown]
# # Table of Contents
#
# 1. [Problem Statement](#section1)<br>
# 2. [Data Loading and Description](#section2)
# 3. [Data Profiling](#section3)
#    - 3.0<br/>
#     - 3.1 [Understanding the Dataset](#section301)<br/>
#     - 3.2 [Pre Profiling](#section302)<br/>
#     - 3.3 [Post Profiling](#section303)<br/><br/>
#
# 4. [Questions- Basic EDA](#section4)<br/>
#    - 4.1 <br/>
#     - 4.1.0 [Count of Candies by different flavors](#section401)<br/>
#     - 4.1.1 [Chocolate Candies Vs WinPercent](#section402)<br/>
#     - 4.1.2 [Chocolate Candies Vs SugarPercent](#section403)<br/>
#     - 4.1.3 [Chocolate Vs Price Percent](#section404)<br/>
#     - 4.1.4 [Chocolate Candies Vs Other features](#section406)<br/>
#
#    - 4.2
#     - 4.2.0 [Numeric Variables(WinPercent,PricePercent,SugarPercent) Line Trends](#section407)<br/>
#
#    - 4.3
#     - 4.3.0 [Scatter plots of Numeric Variables](#section408)<br/>
#
#    - 4.4
#     - 4.4.0 [Fruity Candies Vs WinPercent](#section409)<br/>
#     - 4.4.1 [Fruity Candies Vs Sugarpercent](#section410)<br/>
#     - 4.4.2 [Fruity Candies Vs Price Percent](#section411)<br/>
#     - 4.4.3 [Fruity Candies Vs Other features](#section412)<br/
#
#    - 4.5
#     - 4.5.0 [Caramel Candies Vs Winpercent](#section413)<br/>
#     - 4.5.1 [Caramel Candies Vs Sugar percent](#section414)<br/>
#     - 4.5.2 [Caramel Candies Vs Price Percent](#section415)<br/>
#     - 4.5.3 [Caramel Candies Vs Other Features](#section416)<br/>
#
#    - 4.6
#     - 4.6.0 [Peanutyalmondy Candies Vs Winpercent](#section417)<br/>
#     - 4.6.1 [Peanutyalmondy Candies Vs Sugar percent](#section418)<br/>
#     - 4.6.2 [Peanutyalmondy Candies Vs Price Percent](#section419)<br/>
#     - 4.6.3 [Peanutyalmondy Candies Vs Other Features](#section420)<br/>
#
#    - 4.7
#     - 4.7.0 [Nougat Candies Vs Winpercent](#section421)<br/>
#     - 4.7.1 [Nougat Candies Vs Sugar percent](#section422)<br/>
#     - 4.7.2 [Nougat Candies Vs Price Percent](#section423)<br/>
#     - 4.7.3 [Nougat Candies Vs Other Features](#section424)<br/>
#
#    - 4.8
#     - 4.8.0 [Crispedricewafer Candies Vs Winpercent](#section425)<br/>
#     - 4.8.1 [Crispedricewafer Candies Vs Sugar percent](#section426)<br/>
#     - 4.8.2 [Crispedricewafer Candies Vs Price Percent](#section427)<br/>
#     - 4.8.3 [Crispedricewafer Candies Vs Other Features](#section428)<br/>
#
#    - 4.9
#     - 4.9.0 [Hard Candies Vs Winpercent](#section429)<br/>
#     - 4.9.1 [Hard Candies Vs Sugar percent](#section430)<br/>
#     - 4.9.2 [Hard Candies Vs Price Percent](#section431)<br/>
#     - 4.9.3 [Hard Candies Vs Other Features](#section432)<br/>
#
#    - 4.10
#     - 4.10.0 [Bar Candies Vs Winpercent](#section433)<br/>
#     - 4.10.1 [Bar Candies Vs Sugar percent](#section434)<br/>
#     - 4.10.2 [Bar Candies Vs Price Percent](#section435)<br/>
#     - 4.10.3 [Bar Candies Vs Other Features](#section436)<br/>
#
#    - 5.0
#     - 5.1 [Understanding Correlations among variables/features](#section437)<br/>
#
#    - 6.0
#     - 6.1 [Model Building](#section438) <br/>
#      - 6.1.0 [Preparing x and y using pandas](#section439) <br/>
#      - 6.1.1 [Splitting X and Y into training and test datasets](#section440)<br/>
#      - 6.1.2 [Linear regression in scikit-learn](#section441)<br/>
#      - 6.1.3 [Interpreting Model Coefficients](#section442) <br/>
#      - 6.1.4 [Using the Model for Prediction](#section443)<br/>
#      - 6.1.5 [Model Evaluation using Metrics](#section444) <br/>
#       - 6.1.5.0 [Mean absolute Error](#section445)<br/>
#       - 6.1.5.1 [Mean Squared Error](#section446)<br/>
#       - 6.1.5.2 [Root Mean Squared Error](#section447)<br/>
#      - 6.1.6 [Model Evaluation using Rsquared value](#section448)<br/>
#
#    - 7.0
#     - 7.0 [Feature Selection](#section449) <br/>
#      - 7.1 [Splitting X and Y into training and test datasets](#section450)<br/>
#      - 7.2 [Linear regression in scikit-learn](#section451)<br/>
#      - 7.3 [Interpreting Model Coefficients](#section452) <br/>
#      - 7.4 [Using the Model for Prediction](#section453)<br/>
#      - 7.5 [Model Evaluation using Metrics](#section454) <br/>
#       - 7.5.1 [Mean absolute Error](#section455)<br/>
#       - 7.5.2 [Mean Squared Error](#section456)<br/>
#       - 7.5.3 [Root Mean Squared Error](#section457)<br/>
#       - 7.5.4 [Model Evaluation using Rsquared value](#section458)<br/>
#
#    - 8.0 <br/>
#     - 8.1 [Conclusions](#section459)<br/>

# %% [markdown]
# ### 1. Problem Statement

# %% [markdown]
# The Context of dataset was to find __What’s the best (or at least the most popular) Halloween candy?__
# Data was collected by creating a website where participants were shown presenting two fun-sized candies and asked to click on the one they would prefer to receive. In total, more than 269 thousand votes were collected from 8,371 different IP addresses.

# %% [markdown]
# ### 2. Data Loading and Description
# <img src="c1.png" width="300" height="500" />

# %% [markdown]
# #### Importing the Packages

# %%
import numpy as np                                                 # Implemennts milti-dimensional array and matrices
import pandas as pd                                                # For data manipulation and analysis
import pandas_profiling
import matplotlib.pyplot as plt                                    # Plotting library for Python programming language and it's numerical mathematics extension NumPy
import seaborn as sns                                              # Provides a high level interface for drawing attractive and informative statistical graphics
import warnings                                                                 # Ignore warning related to pandas_profiling
warnings.filterwarnings('ignore') 
# %matplotlib inline
sns.set()
from subprocess import check_output

# %% [markdown]
# #### Importing the Dataset

# %%
candy_df=pd.read_csv('C:\\Users\\DELL\\MachineLearningProject\\ProjectCandy\\Candy.csv')

# %%
candy_df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# 5                   Almond Joy          1       0        0               1
# 6                    Baby Ruth          1       0        1               1
# 7           Boston Baked Beans          0       0        0               1
# 8                   Candy Corn          0       0        0               0
# 9           Caramel Apple Pops          0       1        1               0
# 10             Charleston Chew          1       0        0               0
# ...

# %% [markdown]
# - The Data set contains different flavors presence/absence in different halloween candy brands. Data set consists of various variables.
# -  Dataset consists of 85 enries and 13 columns. Below is the table showing names of all columns and their description

# %% [markdown]
# | Column Name        | Description |
# - - - - - - - - - - -|- - -- -- - - - -- - - -- - -
# | competitor Name    | Name of competitor brand
# | chocolate          | Does it contain chocolate?|
# | fruity             | Is it fruit flavored?|
# | caramel            | Is there caramel in the candy?|
# | peanutalmondy      | Does it contain peanuts, peanut butter or almonds?|
# | nougat             | Does it contain nougat?|
# | crispedricewafer   | Does it contain crisped rice, wafers, or a cookie component|
# | hard               | Is it a hard candy?|
# | bar                | Is it a candy bar?|
# | pluribus           | Is it one of many candies in a bag or box?|
# | sugarpercent       | The percentile of sugar it falls under within the data set|
# | pricepercent       | The unit price percentile compared to the rest of the set|
# | winpercent         | The overall win percentage according to 269,000 matchups|

# %% [markdown]
# ## 3. Data profiling

# %% [markdown]
# - In the upcoming sections we will first __understand our dataset__ using various pandas functionalities.
# - Then with the help of __pandas profiling__ we will find which columns of our dataset need preprocessing.
# - In __preprocessing__ we will deal with erronous and missing values of columns.
# - Again we will do __pandas profiling__ to see how preprocessing have transformed our dataset.

# %%
candy_df.shape # Retrieves the dimensions of data that is rows * columns
# Out:
# (85, 13)

# %%
candy_df.index # Retrieves the step index of records in the Dataset
# Out:
# RangeIndex(start=0, stop=85, step=1)

# %%
candy_df.columns # Retrieves all columns from the Dataset
# Out:
# Index(['competitorname', 'chocolate', 'fruity', 'caramel', 'peanutyalmondy',
#        'nougat', 'crispedricewafer', 'hard', 'bar', 'pluribus', 'sugarpercent',
#        'pricepercent', 'winpercent'],
#       dtype='object')

# %%
candy_df.head(5) # Retrieves first 5 candies data from the dataset
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
candy_df.tail(5) # Retrieves last 5 candies data from dataset
# Out:
#                competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 80                  Twizzlers          0       1        0               0
# 81                   Warheads          0       1        0               0
# 82        Welchs Fruit Snacks          0       1        0               0
# 83  Werthers Original Caramel          0       0        1               0
# 84                   Whoppers          1       0        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 80       0                 0     0    0         0         0.220         0.116
# 81       0                 0     1    0         0         0.093         0.116
# 82       0                 0     0    0         1         0.313         0.313
# 83       0                 0     1    0         0         0.186         0.267
# 84       0                 1     0    0         1         0.872         0.848
#
#     winpercent
# 80   45.466282
# 81   39.011898
# ...

# %%
candy_df.info() # Retrieves count of records for each column, memory usgae, datatypes used in Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 13 columns):
# competitorname      85 non-null object
# chocolate           85 non-null int64
# fruity              85 non-null int64
# caramel             85 non-null int64
# peanutyalmondy      85 non-null int64
# nougat              85 non-null int64
# crispedricewafer    85 non-null int64
# hard                85 non-null int64
# bar                 85 non-null int64
# pluribus            85 non-null int64
# sugarpercent        85 non-null float64
# pricepercent        85 non-null float64
# winpercent          85 non-null float64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 8.7+ KB

# %% [markdown]
# Here, if we observe there are no null objects that is __no missing data__

# %%
candy_df.describe() # Retrieves statistical measures of all columns in the Dataset
# Out:
#        chocolate     fruity    caramel  peanutyalmondy     nougat  \
# count  85.000000  85.000000  85.000000       85.000000  85.000000
# mean    0.435294   0.447059   0.164706        0.164706   0.082353
# std     0.498738   0.500140   0.373116        0.373116   0.276533
# min     0.000000   0.000000   0.000000        0.000000   0.000000
# 25%     0.000000   0.000000   0.000000        0.000000   0.000000
# 50%     0.000000   0.000000   0.000000        0.000000   0.000000
# 75%     1.000000   1.000000   0.000000        0.000000   0.000000
# max     1.000000   1.000000   1.000000        1.000000   1.000000
#
#        crispedricewafer       hard        bar   pluribus  sugarpercent  \
# count         85.000000  85.000000  85.000000  85.000000     85.000000
# mean           0.082353   0.176471   0.247059   0.517647      0.478647
# std            0.276533   0.383482   0.433861   0.502654      0.282778
# min            0.000000   0.000000   0.000000   0.000000      0.011000
# ...

# %%
 candy_df.competitorname.unique() # Returns the unique values of "competitor Name" column in the dataset
# Out:
# array(['100 Grand', '3 Musketeers', 'One dime', 'One quarter',
#        'Air Heads', 'Almond Joy', 'Baby Ruth', 'Boston Baked Beans',
#        'Candy Corn', 'Caramel Apple Pops', 'Charleston Chew',
#        'Chewey Lemonhead Fruit Mix', 'Chiclets', 'Dots', 'Dum Dums',
#        'Fruit Chews', 'Fun Dip', 'Gobstopper', 'Haribo Gold Bears',
#        'Haribo Happy Cola', 'Haribo Sour Bears', 'Haribo Twin Snakes',
#        'Hersheys Kisses', 'Hersheys Krackel', 'Hersheys Milk Chocolate',
#        'Hersheys Special Dark', 'Jawbusters', 'Junior Mints', 'Kit Kat',
#        'Laffy Taffy', 'Lemonhead', 'Lifesavers big ring gummies',
#        'Peanut butter M&Ms', 'M&Ms', 'Mike & Ike', 'Milk Duds',
#        'Milky Way', 'Milky Way Midnight', 'Milky Way Simply Caramel',
#        'Mounds', 'Mr Good Bar', 'Nerds', 'Nestle Butterfinger',
#        'Nestle Crunch', 'Nik L Nip', 'Now & Later', 'Payday',
#        'Peanut M&Ms', 'Pixie Sticks', 'Pop Rocks', 'Red vines',
# ...

# %%
candy_df.competitorname.nunique() # Returns the count of unique values for "Competitor Name" column in the dataset
# Out:
# 85

# %%
candy_df.isnull().sum() # returns count of null values for each column
# Out:
# competitorname      0
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# dtype: int64

# %% [markdown]
# From the above output, it is shown that **no** columns have **null** **value**s

# %% [markdown]
# ### 3.2 Pre Profiling

# %% [markdown]
# - By pandas profiling, an __interactive HTML report__ gets generated which contins all the information about the columns of the dataset, like the __counts and type__ of each _column_. Detailed information about each column, __coorelation between different columns__ and a sample of dataset.<br/>
# - It gives us __visual interpretation__ of each column in the data.
# - _Spread of the data_ can be better understood by the distribution plot.
# - _Grannular level_ analysis of each column.

# %%
profile = pandas_profiling.ProfileReport(candy_df)
profile.to_file(outputfile="candy_df_before_preprocessing.html")

# %% [markdown]
# Here, we have done Pandas Profiling before preprocessing our dataset, so we have named the html file as __candy_df_before_preprocessing.html__. Take a look at the file and see what useful insight you can develop from it. <br/>
# Now we will process our data to better understand it.
# And after we observe the files, there is no missing data or duplicates for any of the columns

# %%
candy_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Here, we observe that there no duplicate records of candies in our Dataset

# %% [markdown]
# ### 3.3 Post Pandas Profiling

# %%
import pandas_profiling
profile=pandas_profiling.ProfileReport(candy_df)
profile.to_file(outputfile="candy_df_after_processing.html")

# %% [markdown]
# There is not much to pre-process the data. So, the pandas profiling report which we have generated after preprocessing will give us more beneficial insights, We can compare the two reports, i.e __candy_df_before_preprocessing.html__ and __candy_df_after_processing.html__<br/>
# In candy_df_after_processing.html report, observations:
# - In the Dataset info, Total __Missing(%)__ = __0.0%__
# - Number of __variables__ = __13__
# - Number of __Observations__ = __85__
# - Variable Types -
# - Numeric variable types are 3,they are __pricepercent__,__sugarpercent__,__winpercent__
# - Cataegorical variable type is one that is __competitorname__
# - Boolean categorical variable types are 9,they are __chocolate__,__caramel__,__bar__,__crispedricewafer__,__fruity__,__peanutyalmondy__,__nougat__,__hard__,__pluribus__

# %% [markdown]
# ### 4. Questions

# %% [markdown]
# ### 4.1.0 Count of Candies by different flavors

# %%
sns.countplot(x="chocolate",palette="spring",data=candy_df).set_title('Count of Candies by Chocolate flavor',color="purple")
# Out:
# Text(0.5,1,'Count of Candies by Chocolate flavor')

# %% [markdown]
# Here, if we observe most of the candies do not contain chocolate flavor in them

# %%
sns.countplot(x="fruity",palette="winter",data=candy_df).set_title('Count of Candies by Fruity flavor',color="purple")
# Out:
# Text(0.5,1,'Count of Candies by Fruity flavor')

# %% [markdown]
# Here, if we observe most of the candies do not contain fruity flavor in them

# %%
sns.countplot(x="caramel",palette="terrain", data=candy_df).set_title("Count of Candies by Caramel flavor", color="purple")
# Out:
# Text(0.5,1,'Count of Candies by Caramel flavor')

# %% [markdown]
# Here, if we observe most of the candies do not contain caramel flavor in them

# %%
sns.countplot(x="peanutyalmondy",palette="Dark2",data=candy_df).set_title("Count of Candies by Peanutyalmondy flavor",color="purple")
# Out:
# Text(0.5,1,'Count of Candies by Peanutyalmondy flavor')

# %% [markdown]
# Here, if we observe most of the candies do not contain peanutyalmondy flavor in them

# %%
sns.countplot(x="nougat",palette="autumn",data=candy_df).set_title("Count of Candies by Nougat flavor",color="purple")
# Out:
# Text(0.5,1,'Count of Candies by Nougat flavor')

# %% [markdown]
# Here, if we observe most of the candies do not contain Nougat flavor in them

# %%
sns.countplot(x="crispedricewafer",palette="magma",data=candy_df).set_title("Count of Candies by Crispedricewafer flavor", color="purple")
# Out:
# Text(0.5,1,'Count of Candies by Crispedricewafer flavor')

# %% [markdown]
# Here, if we observe most of the candies do not contain Crispedricewafer flavor in them

# %%
sns.countplot(x="hard",palette="mako",data=candy_df).set_title("Count of Hard Candies", color="purple")
# Out:
# Text(0.5,1,'Count of Hard Candies')

# %% [markdown]
# Here, if we observe most of the candies are not hard in nature

# %%
sns.countplot(x="bar",palette="rocket",data=candy_df).set_title("Count of Bar Candies", color="purple")
# Out:
# Text(0.5,1,'Count of Bar Candies')

# %% [markdown]
# Here, if we observe most of the candies are not bar candies

# %%
sns.countplot(x="pluribus",palette="nipy_spectral",data=candy_df).set_title("Count of pluribus Candies", color="purple")
# Out:
# Text(0.5,1,'Count of pluribus Candies')

# %% [markdown]
# Here, if we observe most of the candies are pluribus candies means they are one of all remaining candies in the bag

# %% [markdown]
# ### 4.1.1 Chocolate Candies Vs WinPercent

# %%
candy_df.winpercent.nunique()
# Out:
# 85

# %% [markdown]
# Here, we have all unique winpercent for each competitor names that is no winpercent is clashing with each other

# %%
candy_df.sort_values('winpercent')
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 44                   Nik L Nip          0       1        0               0
# 7           Boston Baked Beans          0       0        0               1
# 12                    Chiclets          0       1        0               0
# 72                Super Bubble          0       1        0               0
# 26                  Jawbusters          0       1        0               0
# 57           Root Beer Barrels          0       0        0               0
# 71                 Sugar Daddy          0       0        1               0
# 2                     One dime          0       0        0               0
# 70                Sugar Babies          0       0        1               0
# 19           Haribo Happy Cola          0       0        0               0
# 9           Caramel Apple Pops          0       1        1               0
# ...

# %%
candy_df.winpercent.nlargest(15)
# Out:
# 52    84.180290
# 51    81.866257
# 79    81.642914
# 28    76.768600
# 64    76.673782
# 53    73.434990
# 36    73.099556
# 54    72.887901
# 32    71.465050
# 42    70.735641
# 47    69.483788
# 1     67.602936
# 68    67.037628
# 0     66.971725
# 33    66.574585
# Name: winpercent, dtype: float64

# %% [markdown]
# Here, if we observe , highest winpercent value is __84.180290__ and almost top 3 winpercentages lie in 80's range

# %%
candy_df.winpercent.nsmallest(15)
# Out:
# 44    22.445341
# 7     23.417824
# 12    24.524988
# 72    27.303865
# 26    28.127439
# 57    29.703691
# 71    32.230995
# 2     32.261086
# 70    33.437550
# 19    34.158958
# 9     34.517681
# 69    34.578991
# 59    34.722000
# 55    35.290756
# 11    36.017628
# Name: winpercent, dtype: float64

# %% [markdown]
# Here, if we observe , lowest winpercent value is __22.445341__ and almost least 3 winpercentages lie in 20's range

# %%
candy_df['chocolate_present'] = candy_df['chocolate'].apply(lambda x: 'yes' if x == 1 else 'no')
candy_df['chocolate_present']
# Out:
# 0     yes
# 1     yes
# 2      no
# 3      no
# 4      no
# 5     yes
# 6     yes
# 7      no
# 8      no
# 9      no
# 10    yes
# 11     no
# 12     no
# 13     no
# 14     no
# 15     no
# 16     no
# 17     no
# 18     no
# 19     no
# 20     no
# 21     no
# 22    yes
# 23    yes
# 24    yes
# 25    yes
# 26     no
# 27    yes
# 28    yes
# 29     no
#      ...
# 55     no
# 56    yes
# 57     no
# 58     no
# 59    yes
# 60     no
# 61     no
# 62    yes
# 63     no
# 64    yes
# 65    yes
# 66     no
# 67     no
# 68     no
# 69     no
# 70     no
# 71     no
# 72     no
# 73     no
# 74    yes
# 75    yes
# 76    yes
# 77    yes
# 78     no
# 79    yes
# 80     no
# 81     no
# 82     no
# 83     no
# 84    yes
# Name: chocolate_present, Length: 85, dtype: object

# %%
candy_df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# 5                   Almond Joy          1       0        0               1
# 6                    Baby Ruth          1       0        1               1
# 7           Boston Baked Beans          0       0        0               1
# 8                   Candy Corn          0       0        0               0
# 9           Caramel Apple Pops          0       1        1               0
# 10             Charleston Chew          1       0        0               0
# ...

# %%
g1 = candy_df.groupby('chocolate_present')
for group,values in g1:
    print("Chocolate Presence: "+group)
    print(values.nlargest(15,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Chocolate Presence: no
#                  competitorname  winpercent
# 68                    Starburst   67.037628
# 60            Skittles original   63.085140
# 66              Sour Patch Kids   59.863998
# 18            Haribo Gold Bears   57.119740
# 41                        Nerds   55.354046
# 61           Skittles wildberry   55.103695
# 73                 Swedish Fish   54.861111
# 31  Lifesavers big ring gummies   52.911392
# 67        Sour Patch Tricksters   52.825947
# 4                     Air Heads   52.341465
# 20            Haribo Sour Bears   51.412430
# 78            Trolli Sour Bites   47.173229
# 17                   Gobstopper   46.783348
# 34                   Mike & Ike   46.411716
# 46                       Payday   46.296597
# ------
# Chocolate Presence: yes
#                 competitorname  winpercent
# 52    Reeses Peanut Butter cup   84.180290
# 51           Reeses Miniatures   81.866257
# 79                        Twix   81.642914
# ...

# %% [markdown]
# Here,if we observe __Reeses Peanut Butter cup, Reeses Miniatures, Twix__ candies have been liked by many people since their win percentages are __84.180290,81.866257,81.642914__ and it contains chocolate flavor in it that means mostly chocolate candies are highly selected by matchups during halloween

# %% [markdown]
# Here,if we observe __Starburst, Skittles original, Sour Patch Kids__ candies have also been liked by few people since their win percentages are __67.037628,63.085140,59.863998__ and those candies does not contain chocolate flavor in them

# %%
g2 = candy_df.groupby('chocolate_present')
for group,values in g2:
    print("Chocolate Presence: "+group)
    print(values.nsmallest(15,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Chocolate Presence: no
#                 competitorname  winpercent
# 44                   Nik L Nip   22.445341
# 7           Boston Baked Beans   23.417824
# 12                    Chiclets   24.524988
# 72                Super Bubble   27.303865
# 26                  Jawbusters   28.127439
# 57           Root Beer Barrels   29.703691
# 71                 Sugar Daddy   32.230995
# 2                     One dime   32.261086
# 70                Sugar Babies   33.437550
# 19           Haribo Happy Cola   34.158958
# 9           Caramel Apple Pops   34.517681
# 69         Strawberry bon bons   34.578991
# 55                    Ring pop   35.290756
# 11  Chewey Lemonhead Fruit Mix   36.017628
# 50                   Red vines   37.348522
# ------
# Chocolate Presence: yes
#              competitorname  winpercent
# 59                  Sixlets   34.722000
# 62          Nestle Smarties   37.887188
# 10          Charleston Chew   38.975037
# 75     Tootsie Roll Juniors   43.068897
# ...

# %% [markdown]
# Here,if we observe __Nik L Nip, Boston Baked Beans and Chiclets__ candies have not been been liked by many people since their win percentages are low __22.445341,23.417824,24.524988__ and these candies does not contain chocolate flavor in it, that means low win percentage chocolates are not chocolate candies, I mean people like if candy contains chocolate in it

# %% [markdown]
# Here,if we observe __Sixlets, Nestle Smarties and Charleston Chew__ candies have been been liked by few people since their win percentages are medium __34.722000,37.887188,38.975037__ and these candies does contain chocolate flavor in it, that means a bit more compared to above cell

# %%
candy_df[["winpercent","chocolate"]].plot.scatter(x="chocolate",y="winpercent",color="Blue").set_title("Chocolate Vs Winpercent",color="purple")
# Out:
# Text(0.5,1,'Chocolate Vs Winpercent')

# %% [markdown]
# Here, if we observe candies with __no chocolate flavor have low winpercentages than candies containing chocolate flavor__ that is people are liking candies with chocolate flavor more

# %% [markdown]
# ### 4.1.2 Chocolate Candies Vs Sugar Percent

# %%
candy_df.sugarpercent.nunique()
# Out:
# 34

# %% [markdown]
# Here, this indicates that many of the candies have __same sugarpercent__ content in them because there are only 34 unique values

# %%
candy_df.sort_values('sugarpercent')
# Out:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 2                      One dime          0       0        0               0
# 3                   One quarter          0       0        0               0
# 51            Reeses Miniatures          1       0        0               1
# 30                    Lemonhead          0       1        0               0
# 12                     Chiclets          0       1        0               0
# 66              Sour Patch Kids          0       1        0               0
# 67        Sour Patch Tricksters          0       1        0               0
# 48                 Pixie Sticks          0       0        0               0
# 26                   Jawbusters          0       1        0               0
# 81                     Warheads          0       1        0               0
# 22              Hersheys Kisses          1       0        0               0
# ...

# %%
candy_df.sugarpercent.nlargest(15)
# Out:
# 54    0.988
# 38    0.965
# 70    0.965
# 60    0.941
# 61    0.941
# 4     0.906
# 8     0.906
# 17    0.906
# 34    0.872
# 58    0.872
# 84    0.872
# 56    0.860
# 41    0.848
# 32    0.825
# 33    0.825
# Name: sugarpercent, dtype: float64

# %% [markdown]
# Here if we observe, the top sugarpercent is almost equal to 1 percent and top sugarpercents presence in candies are __0.988,0.965,0.941__

# %%
candy_df.sugarpercent.nsmallest(15)
# Out:
# 2     0.011
# 3     0.011
# 51    0.034
# 12    0.046
# 30    0.046
# 66    0.069
# 67    0.069
# 26    0.093
# 48    0.093
# 81    0.093
# 15    0.127
# 22    0.127
# 68    0.151
# 72    0.162
# 76    0.174
# Name: sugarpercent, dtype: float64

# %% [markdown]
# Here if we observe, the least sugarpercent is almost equal to 0 percent and least sugarpercents presence in candies are __0.011,0.034,0.046__

# %%
h1 = candy_df.groupby('chocolate_present')
for group,values in h1:
    print("Chocolate Presence: "+group)
    print(values.nlargest(15,'sugarpercent')[['competitorname','sugarpercent']])
    print('------')
# Out:
# Chocolate Presence: no
#                 competitorname  sugarpercent
# 70                Sugar Babies         0.965
# 60           Skittles original         0.941
# 61          Skittles wildberry         0.941
# 4                    Air Heads         0.906
# 8                   Candy Corn         0.906
# 17                  Gobstopper         0.906
# 34                  Mike & Ike         0.872
# 58                       Runts         0.872
# 41                       Nerds         0.848
# 11  Chewey Lemonhead Fruit Mix         0.732
# 13                        Dots         0.732
# 14                    Dum Dums         0.732
# 16                     Fun Dip         0.732
# 55                    Ring pop         0.732
# 57           Root Beer Barrels         0.732
# ------
# Chocolate Presence: yes
#                 competitorname  sugarpercent
# 54  Reeses stuffed with pieces         0.988
# 38    Milky Way Simply Caramel         0.965
# 84                    Whoppers         0.872
# ...

# %% [markdown]
# Here, if we observe most of the candies __irrespective of chocolate flavored or non chocolate flavor are having high sugarpercent__ that means __chocolate feature has much nothing to do with sugarpercent in the candy__

# %%
h2 = candy_df.groupby('chocolate_present')
for group,values in h2:
    print("Chocolate Presence: "+group)
    print(values.nsmallest(15,'sugarpercent')[['competitorname','sugarpercent']])
    print('------')
# Out:
# Chocolate Presence: no
#                competitorname  sugarpercent
# 2                    One dime         0.011
# 3                 One quarter         0.011
# 12                   Chiclets         0.046
# 30                  Lemonhead         0.046
# 66            Sour Patch Kids         0.069
# 67      Sour Patch Tricksters         0.069
# 26                 Jawbusters         0.093
# 48               Pixie Sticks         0.093
# 81                   Warheads         0.093
# 15                Fruit Chews         0.127
# 68                  Starburst         0.151
# 72               Super Bubble         0.162
# 83  Werthers Original Caramel         0.186
# 44                  Nik L Nip         0.197
# 29                Laffy Taffy         0.220
# ------
# Chocolate Presence: yes
#              competitorname  sugarpercent
# 51        Reeses Miniatures         0.034
# 22          Hersheys Kisses         0.127
# 76     Tootsie Roll Midgies         0.174
# ...

# %% [markdown]
# Here, if we observe the table __candies of non chocolate flavoe have low sugar percent than candies with chocolate flavor__

# %%
candy_df[["chocolate","sugarpercent"]].plot.scatter(x="chocolate",y="sugarpercent",color="Red").set_title("Chocolate Vs Sugar percent",color="purple")
# Out:
# Text(0.5,1,'Chocolate Vs Sugar percent')

# %% [markdown]
# Here, if we observe it is almost same that is __sugar percent is almost same in candies that are with chocolate flavor or without chocolate flavor__ that is __sugarpercent not much influential with chocolate flavor feature__

# %% [markdown]
# ### 4.1.3 Chocolate Vs Price Percent

# %%
candy_df.pricepercent.nunique()
# Out:
# 29

# %% [markdown]
# Here, this indicates that many of the candies have __same pricepercent__ because there are only __29__ unique values and almost many candies are of same price

# %%
candy_df.sort_values('pricepercent')
# Out:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 76         Tootsie Roll Midgies          1       0        0               0
# 48                 Pixie Sticks          0       0        0               0
# 15                  Fruit Chews          0       1        0               0
# 14                     Dum Dums          0       1        0               0
# 69          Strawberry bon bons          0       1        0               0
# 57            Root Beer Barrels          0       0        0               0
# 59                      Sixlets          1       0        0               0
# 22              Hersheys Kisses          1       0        0               0
# 30                    Lemonhead          0       1        0               0
# 63               Smarties candy          0       1        0               0
# 50                    Red vines          0       1        0               0
# ...

# %%
candy_df.pricepercent.nlargest(15)
# Out:
# 44    0.976
# 62    0.976
# 55    0.965
# 23    0.918
# 24    0.918
# 25    0.918
# 40    0.918
# 79    0.906
# 0     0.860
# 38    0.860
# 39    0.860
# 56    0.860
# 84    0.848
# 49    0.837
# 5     0.767
# Name: pricepercent, dtype: float64

# %%
candy_df.pricepercent.nsmallest(15)
# Out:
# 76    0.011
# 48    0.023
# 14    0.034
# 15    0.034
# 69    0.058
# 57    0.069
# 59    0.081
# 22    0.093
# 30    0.104
# 2     0.116
# 29    0.116
# 50    0.116
# 63    0.116
# 66    0.116
# 67    0.116
# Name: pricepercent, dtype: float64

# %%
i1 = candy_df.groupby('chocolate_present')
for group,values in i1:
    print("Chocolate Presence: "+group)
    print(values.nlargest(15,'pricepercent')[['competitorname','pricepercent']])
    print('------')
# Out:
# Chocolate Presence: no
#                 competitorname  pricepercent
# 44                   Nik L Nip         0.976
# 55                    Ring pop         0.965
# 49                   Pop Rocks         0.837
# 46                      Payday         0.767
# 70                Sugar Babies         0.767
# 73                Swedish Fish         0.755
# 3                  One quarter         0.511
# 4                    Air Heads         0.511
# 7           Boston Baked Beans         0.511
# 11  Chewey Lemonhead Fruit Mix         0.511
# 13                        Dots         0.511
# 26                  Jawbusters         0.511
# 18           Haribo Gold Bears         0.465
# 19           Haribo Happy Cola         0.465
# 20           Haribo Sour Bears         0.465
# ------
# Chocolate Presence: yes
#               competitorname  pricepercent
# 62           Nestle Smarties         0.976
# 23          Hersheys Krackel         0.918
# 24   Hersheys Milk Chocolate         0.918
# ...

# %% [markdown]
# Here, if we observe __candies with chocolate flavor are a bit costly or have high price percent than chocolates with no chocolate flavor__

# %%
i2=candy_df.groupby("chocolate_present")
for group,values in i2:
    print("chocolate presence: "+group)
    print(values.nsmallest(15,'pricepercent')[['competitorname','pricepercent']])
    print('________________')
# Out:
# chocolate presence: no
#            competitorname  pricepercent
# 48           Pixie Sticks         0.023
# 14               Dum Dums         0.034
# 15            Fruit Chews         0.034
# 69    Strawberry bon bons         0.058
# 57      Root Beer Barrels         0.069
# 30              Lemonhead         0.104
# 2                One dime         0.116
# 29            Laffy Taffy         0.116
# 50              Red vines         0.116
# 63         Smarties candy         0.116
# 66        Sour Patch Kids         0.116
# 67  Sour Patch Tricksters         0.116
# 72           Super Bubble         0.116
# 80              Twizzlers         0.116
# 81               Warheads         0.116
# ________________
# chocolate presence: yes
#              competitorname  pricepercent
# 76     Tootsie Roll Midgies         0.011
# 59                  Sixlets         0.081
# 22          Hersheys Kisses         0.093
# 51        Reeses Miniatures         0.279
# ...

# %% [markdown]
# Here, if we observe candies with __no chocolate flavor are having less price percent than candies with chocolate flavor__

# %%
candy_df[["chocolate","pricepercent"]].plot.scatter(x="chocolate",y="pricepercent",color="Blue").set_title("Chocolate Vs Price percent",color="purple")
# Out:
# Text(0.5,1,'Chocolate Vs Price percent')

# %% [markdown]
# Here, if we observe the plot, we get to know that candies with __no chocolate flavor have pricepercent cocentrated more near 0.2 and o.4, whereas candies with chocolate flavor have high pricepercent concentated more near 0.8 and 1.0, that means candies with chocolate flavor have a little bit more pricepercent than candies with no chocolate flavor__

# %% [markdown]
# ### 4.1.4 Chocolate Vs Other Features

# %%
sns.countplot(x="chocolate", hue="caramel",palette="cool",data=candy_df).set_title('Chocolate Candies Vs Caramel',color="purple")
# Out:
# Text(0.5,1,'Chocolate Candies Vs Caramel')

# %% [markdown]
# Here, if we observe from above plot, Most of the candies that __don't have chocolate do not contain caramel__ also in them

# %%
sns.countplot(x="chocolate", hue="peanutyalmondy",palette="winter",data=candy_df).set_title('Chocolate Candies Vs Peanutyalmondy',color="purple")
# Out:
# Text(0.5,1,'Chocolate Candies Vs Peanutyalmondy')

# %% [markdown]
# Here, if we observe from above plot, Most of the candies that __don't have chocolate do not contain peanutyalmondy__ also in them

# %%
sns.countplot(x="chocolate", hue="nougat",palette="autumn",data=candy_df).set_title('Chocolate Candies Vs Nougat',color="purple")
# Out:
# Text(0.5,1,'Chocolate Candies Vs Nougat')

# %% [markdown]
# Here, if we observe from above plot, Most of the candies that __don't have chocolate do not contain nougat__ also in them

# %%
sns.countplot(x="chocolate", hue="crispedricewafer",palette="summer",data=candy_df).set_title('Chocolate Candies Vs Crispedricewader',color="purple")
# Out:
# Text(0.5,1,'Chocolate Candies Vs Crispedricewader')

# %% [markdown]
# Here, if we observe from above plot, all candies that __don't have chocolate do not contain crispedricewafer__ also in them

# %%
sns.countplot(x="chocolate", hue="hard",palette="terrain",data=candy_df).set_title('Chocolate Candies Vs Hard Candies',color="purple")
# Out:
# Text(0.5,1,'Chocolate Candies Vs Hard Candies')

# %% [markdown]
# Here, if we observe from above plot, almost most of the candies are __not hard that is candies are soft if they have chocolate flavor in it or not__

# %%
sns.countplot(x="chocolate", hue="bar",palette="hot",data=candy_df).set_title('Chocolate candies Vs Bar Candies',color="purple")
# Out:
# Text(0.5,1,'Chocolate candies Vs Bar Candies')

# %% [markdown]
# Here, if we observe from above plot,most of the candies that __do not have chocolate also are not bar candies, and most of the candies that are of chocolate flavor are bar candies__

# %%
sns.countplot(x="chocolate", hue="fruity",palette="summer",data=candy_df).set_title('Chocolate candies Vs fruity Candies',color="purple")
# Out:
# Text(0.5,1,'Chocolate candies Vs fruity Candies')

# %% [markdown]
# Here, if we observe from above plot, we can say that __fruity and cocolate are not at all related, all(mostly) chocolate candies do not contain fruity in them__

# %% [markdown]
# ### 4.2 Numeric Variables(WinPercent,PricePercent,SugarPercent) Line Trends

# %%
candy_df["winpercent"].plot.line(color="maroon",linewidth=1,title="Winpercent Trend")

# %%
candy_df["winpercent"].plot.hist(color="maroon", title="Winpercent Range")

# %% [markdown]
# Here, from above plot we can see the distribution is a left skewed becuase ,__mean is around 50.30 and winpercentage is highly distributed towards left means many candies have winpercentage less than mean__

# %%
candy_df["pricepercent"].plot.line(color="green",linewidth=1,title="Price percent Trend")

# %%
candy_df["pricepercent"].plot.hist(color="green", title="Pricepercent Range")

# %% [markdown]
# Here, from above plot we can see there is __normal distribution that is all candies have varying pricepercents__

# %%
candy_df["sugarpercent"].plot.line(color="blue",linewidth=1,title="Suagr percent Trend")

# %%
candy_df['sugarpercent'].plot.hist(color="blue",title="SugarPercent Range")

# %% [markdown]
# Here, from above plot, we can say that __sugarpecent is also alomost normally distributed among all candies__

# %% [markdown]
# ### 4.3 Scatter plots of Numeric Variables

# %% [markdown]
# #### Winpercent Vs Price Percent

# %%
candy_df[['winpercent','pricepercent']].plot.scatter(x='winpercent', y='pricepercent', color="DarkMagenta").set_title("Win percent Vs price percent", color="purple")
# Out:
# Text(0.5,1,'Win percent Vs price percent')

# %% [markdown]
# Here,from above scatter plot,we can say that really it is scattered irrespective of winpercentages, that is price percent is not that effective with win percentage means __not that like high price percent of candies have high win percent and viceversa__

# %%
candy_df[['winpercent','sugarpercent']].plot.scatter(x='winpercent', y='sugarpercent', color="blue").set_title("Win percent Vs Sugar percent", color="purple")
# Out:
# Text(0.5,1,'Win percent Vs Sugar percent')

# %% [markdown]
# Here,from above scatter plot,we can say that really it is scattered irrespective of winpercentages, that is sugar percent is not that effective with win percentage means __not that like high sugar percent of candies have high win percent and viceversa__

# %%
candy_df[['pricepercent','sugarpercent']].plot.scatter(x='pricepercent', y='sugarpercent', color="brown").set_title("Price percent Vs Sugar percent", color="purple")
# Out:
# Text(0.5,1,'Price percent Vs Sugar percent')

# %% [markdown]
# Here, from above plot we can say that __price percent increases slightly with sugar percent__

# %% [markdown]
# ### 4.4.0 Fruity Candies Vs WinPercent

# %%
sns.boxplot(x="fruity",y="winpercent",palette="autumn",data=candy_df).set_title("Fruity Candies Vs Winpercent", color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs Winpercent')

# %% [markdown]
# Here, if we observe above box plot, it is understood that candies __with no fruity flavor have high win percents compared to candies with fruity flavor__

# %%
candy_df['fruity_present'] = candy_df['fruity'].apply(lambda x: 'yes' if x == 1 else 'no')
candy_df['fruity_present']
# Out:
# 0      no
# 1      no
# 2      no
# 3      no
# 4     yes
# 5      no
# 6      no
# 7      no
# 8      no
# 9     yes
# 10     no
# 11    yes
# 12    yes
# 13    yes
# 14    yes
# 15    yes
# 16    yes
# 17    yes
# 18    yes
# 19     no
# 20    yes
# 21    yes
# 22     no
# 23     no
# 24     no
# 25     no
# 26    yes
# 27     no
# 28     no
# 29    yes
#      ...
# 55    yes
# 56     no
# 57     no
# 58    yes
# 59     no
# 60    yes
# 61    yes
# 62     no
# 63    yes
# 64     no
# 65     no
# 66    yes
# 67    yes
# 68    yes
# 69    yes
# 70     no
# 71     no
# 72    yes
# 73    yes
# 74    yes
# 75     no
# 76     no
# 77     no
# 78    yes
# 79     no
# 80    yes
# 81    yes
# 82    yes
# 83     no
# 84     no
# Name: fruity_present, Length: 85, dtype: object

# %%
s1=candy_df.groupby('fruity_present')
for group,values in s1:
    print("Fruity_Presence: "+group)
    print(values.nlargest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Fruity_Presence: no
#                 competitorname  winpercent
# 52    Reeses Peanut Butter cup   84.180290
# 51           Reeses Miniatures   81.866257
# 79                        Twix   81.642914
# 28                     Kit Kat   76.768600
# 64                    Snickers   76.673782
# 53               Reeses pieces   73.434990
# 36                   Milky Way   73.099556
# 54  Reeses stuffed with pieces   72.887901
# 32          Peanut butter M&Ms   71.465050
# 42         Nestle Butterfinger   70.735641
# ------
# Fruity_Presence: yes
#                  competitorname  winpercent
# 68                    Starburst   67.037628
# 60            Skittles original   63.085140
# 66              Sour Patch Kids   59.863998
# 18            Haribo Gold Bears   57.119740
# 41                        Nerds   55.354046
# 61           Skittles wildberry   55.103695
# 73                 Swedish Fish   54.861111
# 31  Lifesavers big ring gummies   52.911392
# ...

# %% [markdown]
# Here if we observe, __top high win percent candies have no fruity flavor in them and top 3 candies that do not have fruity flavor are Reeses Peanut Butter cup, Reeses Miniatures, Twix candies__

# %% [markdown]
# Here if we observe fruity flavored candies have win percents of __67.037628,63.085140,59.863998__ and top 3 competitors are __Starburst,Skittles original,Sour Patch Kids__ __

# %%
s2=candy_df.groupby('fruity_present')
for group,values in s2:
    print("Fruity_Presence: "+group)
    print(values.nsmallest(10,'winpercent')[['competitorname','winpercent']])
    print('------------')
# Out:
# Fruity_Presence: no
#         competitorname  winpercent
# 7   Boston Baked Beans   23.417824
# 57   Root Beer Barrels   29.703691
# 71         Sugar Daddy   32.230995
# 2             One dime   32.261086
# 70        Sugar Babies   33.437550
# 19   Haribo Happy Cola   34.158958
# 59             Sixlets   34.722000
# 48        Pixie Sticks   37.722336
# 62     Nestle Smarties   37.887188
# 8           Candy Corn   38.010963
# ------------
# Fruity_Presence: yes
#                 competitorname  winpercent
# 44                   Nik L Nip   22.445341
# 12                    Chiclets   24.524988
# 72                Super Bubble   27.303865
# 26                  Jawbusters   28.127439
# 9           Caramel Apple Pops   34.517681
# 69         Strawberry bon bons   34.578991
# 55                    Ring pop   35.290756
# 11  Chewey Lemonhead Fruit Mix   36.017628
# 50                   Red vines   37.348522
# 81                    Warheads   39.011898
# ------------

# %% [markdown]
# Here if we observe, almost __fruity candies have low winpercents compared to candies with no fruity flavor__

# %% [markdown]
# ### 4.4.1 Fruity Candies Vs Sugarpercent

# %%
sns.swarmplot(x="fruity",y="sugarpercent",palette="YlOrBr",data=candy_df,linewidth=1).set_title('Fruity Candies Vs Sugarpercent',color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs Sugarpercent')

# %% [markdown]
# Here, from above swarmplot, we can say that almost __sugarpercent has no much effect on fruit flavor candies, it is the same in both type of candies__

# %% [markdown]
# ### 4.4.2 Fruity Candies Vs Price Percent

# %%
sns.violinplot(x="fruity",y="pricepercent",data=candy_df,palette="cool",linewidth=2).set_title("Fruity Candies Vs Price Percent", color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs Price Percent')

# %% [markdown]
# Here, if we observe above violin plot, we can say that most of the candies with __no fruit flavor are having high price percent than candies having fruity flavor__

# %% [markdown]
# ### 4.4.3 Fruity vs Other Features

# %%
sns.barplot(x="fruity", y="winpercent",hue="chocolate",data=candy_df, palette = "autumn").set_title("Fruity Candies Vs Chocolate Candies",color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs Chocolate Candies')

# %% [markdown]
# Here, from above barplot, we can say that most of the candies having __high win percent are only chocolate and non fruity flavored candies__ whereas __both flavored candies having aroung 48-50 winpercents__

# %%
sns.barplot(x="fruity",y="winpercent",hue="caramel",data=candy_df,palette="RdBu").set_title("Fruity Candies Vs Caramel Candies", color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs Caramel Candies')

# %% [markdown]
# Here, from above barplot, we can say that __candies of a bit high percent have caramel flavor but not fruity flavor in them__ and __both flavored candies have winpercents of around 45__

# %%
sns.barplot(x="fruity",y="winpercent",hue="peanutyalmondy",data=candy_df,palette="rainbow").set_title("Fruity Candies Vs peanutyalmondy Candies", color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs peanutyalmondy Candies')

# %% [markdown]
# Here, from above barplot, we can say that __candies with above 60 winpercent are of peanutyalmond flavor and no fruity whereas there are no candies of both flavors__

# %%
sns.barplot(x="fruity",y="winpercent",hue="nougat",data=candy_df,palette="Accent").set_title("Fruity Candies Vs Nougat Candies", color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs Nougat Candies')

# %% [markdown]
# Here, from above barplot, we can say that __candies with 60 winpercent are of nougat flavor and no fruity whereas there are no candies of both flavors__

# %%
sns.barplot(x="fruity",y="winpercent",data=candy_df, hue="crispedricewafer", palette="magma").set_title("Fruity Candies Vs Crispedricewafer Candies",color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs Crispedricewafer Candies')

# %% [markdown]
# Here, from above barplot, we can say that __candies with above 60 winpercent are of crispedricewafer flavor and no fruity whereas there are no candies of both flavors__

# %%
sns.barplot(x="fruity",y="winpercent",data=candy_df, hue="hard", palette="tab10").set_title("Fruity Candies Vs Hard Candies",color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs Hard Candies')

# %% [markdown]
# Here, from above barplot, we can saay that __candies with no hard and fruity flavor are having a bit high win percents compared to both flavored candies and fruit-no hard candies are having winpercents of around 40-45__

# %%
sns.barplot(x="fruity",y="winpercent",data=candy_df, hue="bar", palette="jet_r").set_title("Fruity Candies Vs Bar Candies",color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs Bar Candies')

# %% [markdown]
# Here, from above barplot, we can say that __candies with above 60 winpercent are of no fruity and bar candies whereas there are no candies of bar fruit flavors__

# %%
sns.barplot(x="fruity",y="winpercent",data=candy_df, hue="pluribus", palette="viridis").set_title("Fruity Candies Vs Pluribus Candies",color="purple")
# Out:
# Text(0.5,1,'Fruity Candies Vs Pluribus Candies')

# %% [markdown]
# Here, from above barplot, wee can say that __np pluribus(not one among many candies in the box) are of no fruity flavor have high winpercents__

# %% [markdown]
# ### 4.5.0 Caramel Candies Vs Winpercent

# %%
sns.violinplot(x="caramel",y="winpercent",data=candy_df,palette="hsv").set_title("Caramel Candies vs Win percent", color="purple")
# Out:
# Text(0.5,1,'Caramel Candies vs Win percent')

# %% [markdown]
# Here, most of the __candies having high winpercents like above 60 and near to 100 contain caramel in them__

# %%
candy_df['caramel_present'] = candy_df['caramel'].apply(lambda x: 'yes' if x == 1 else 'no')
candy_df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# 5                   Almond Joy          1       0        0               1
# 6                    Baby Ruth          1       0        1               1
# 7           Boston Baked Beans          0       0        0               1
# 8                   Candy Corn          0       0        0               0
# 9           Caramel Apple Pops          0       1        1               0
# 10             Charleston Chew          1       0        0               0
# ...

# %%
t1=candy_df.groupby('caramel_present')
for group,values in t1:
    print("Caramel_Presence: "+group)
    print(values.nlargest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Caramel_Presence: no
#                 competitorname  winpercent
# 52    Reeses Peanut Butter cup   84.180290
# 51           Reeses Miniatures   81.866257
# 28                     Kit Kat   76.768600
# 53               Reeses pieces   73.434990
# 54  Reeses stuffed with pieces   72.887901
# 32          Peanut butter M&Ms   71.465050
# 42         Nestle Butterfinger   70.735641
# 47                 Peanut M&Ms   69.483788
# 1                 3 Musketeers   67.602936
# 68                   Starburst   67.037628
# ------
# Caramel_Presence: yes
#               competitorname  winpercent
# 79                      Twix   81.642914
# 64                  Snickers   76.673782
# 36                 Milky Way   73.099556
# 0                  100 Grand   66.971725
# 56                      Rolo   65.716286
# 38  Milky Way Simply Caramel   64.353340
# 37        Milky Way Midnight   60.800701
# 65          Snickers Crisper   59.529251
# 6                  Baby Ruth   56.914547
# ...

# %% [markdown]
# Here if we observe, __high win percent candies Reeses Peanut Butter cup, Reeses Miniatures, Twix candies contain caramel and does not contain caramel in them,that means people are liking candies if it contain/not contains caramel in candies__

# %%
t2=candy_df.groupby('caramel_present')
for group,values in t2:
    print("Caramel_Presence: "+group)
    print(values.nsmallest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Caramel_Presence: no
#          competitorname  winpercent
# 44            Nik L Nip   22.445341
# 7    Boston Baked Beans   23.417824
# 12             Chiclets   24.524988
# 72         Super Bubble   27.303865
# 26           Jawbusters   28.127439
# 57    Root Beer Barrels   29.703691
# 2              One dime   32.261086
# 19    Haribo Happy Cola   34.158958
# 69  Strawberry bon bons   34.578991
# 59              Sixlets   34.722000
# ------
# Caramel_Presence: yes
#                competitorname  winpercent
# 71                Sugar Daddy   32.230995
# 70               Sugar Babies   33.437550
# 9          Caramel Apple Pops   34.517681
# 83  Werthers Original Caramel   41.904308
# 35                  Milk Duds   55.064072
# 6                   Baby Ruth   56.914547
# 65           Snickers Crisper   59.529251
# 37         Milky Way Midnight   60.800701
# 38   Milky Way Simply Caramel   64.353340
# 56                       Rolo   65.716286
# ------

# %% [markdown]
# Here, from above grouped table, we can say that __caramel presence gains a little edge over non caramel candies__

# %% [markdown]
# ### 4.5.1 Caramel Candies Vs Sugar percent

# %%
sns.swarmplot(x="caramel",y="sugarpercent",palette="pink",data=candy_df,linewidth=1).set_title('Caramel Candies Vs Sugarpercent',color="purple")
# Out:
# Text(0.5,1,'Caramel Candies Vs Sugarpercent')

# %% [markdown]
# Here, from above swarm plot we can say that __firstly caramel candies are less in count and have suagrpercent of around mean whereas non caramel candies contain almost all levels of sugar in them__

# %% [markdown]
# ### 4.5.2 Caramel Candies Vs Price Percent

# %%
sns.boxplot(x="caramel",y="pricepercent",data=candy_df,palette="nipy_spectral",linewidth=2).set_title("Caramel Candies Vs Price Percent", color="purple")
# Out:
# Text(0.5,1,'Caramel Candies Vs Price Percent')

# %% [markdown]
# Here, from above boxplot, we can say that __caramel candies have high price perent compared to non caramel candies__

# %% [markdown]
# ### 4.5.3 Caramel Candies Vs Other Features

# %%
sns.pairplot(candy_df, hue="caramel",x_vars=["chocolate","fruity","peanutyalmondy"],y_vars="winpercent",height=3.5,kind="reg",markers="*",palette="rocket")

# %% [markdown]
# From above pairplot, we can note following
#
# 1. For Chocolate-Caramel combination, chocolate flavor increases-increase win percent, caramel presence also increases win percent(Reg lines are increasing that is positive regression)
#
# 2. For Fruity-Caramel combination, no fruit and few caramel candies have high winpercent and fruity candies do not have caramel in them(actually presence of fruity candies do not much contribute to win percent-reg lines are downwards, presence/absence of caramel with fruity have less winpercents )
#
# 3. For Peanutyalmondy-Caramel ccombiation,presence of both flavors in candies contribute to high winpercent and absence of peanutalmondy and caramel presence have winpercents growing(even if peanutyalmond presence/absence- caramel has positive reg that is growing winpercents irrespective of peanutalmondy)

# %%
sns.pairplot(candy_df, hue="caramel",x_vars=["nougat","crispedricewafer","hard"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="icefire")

# %% [markdown]
# From above pairplot, we can note following
#
# 1. For Nougat-Caramel combination, no nougat flavor- presence/absence of caramel-increases win percent, caramel,nougat presence also increases win percent(Reg lines are increasing that is positive regression)
#
# 2. For crispedricewafer-Caramel combination,no crispedricewafer flavor- presence/absence of caramel-increases win percent, caramel,crispedricewafer presence also increases win percent(Reg lines are increasing that is positive regression)
#
# 3. For Hard-Caramel combiation,not hard candies have high winpercent and may/may not have caramel in them , thus together alomost good winpercents, but as candies are hard-absence of caramel contribute to less winpercents(reg lines are downwards)

# %%
sns.pairplot(candy_df, hue="caramel",x_vars=["bar","pluribus"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="seismic")

# %% [markdown]
#   From above pairplot, we can note following
#
# 1. For Bar-Caramel combination, non bar candies do not have caramel flavor and have all levels of win percents and bar candiees have caramel and have growing winpercents(Reg lines are increasing that is positive regression)
#
# 2. For pluribus-Caramel combination,almost equal regression lines that means pluribus one among all candies have caramel flavor in them

# %% [markdown]
# ### 4.6.0 PeanutAlmondy Candies Vs Winpercent

# %%
sns.boxplot(x="peanutyalmondy",y="winpercent",data=candy_df, palette="tab20").set_title("PeeanutAlmondy Candies Vs Win Percent", color="purple")
# Out:
# Text(0.5,1,'PeeanutAlmondy Candies Vs Win Percent')

# %% [markdown]
# Here, from above boxplot, we can say that __candies with peanutyalmpndy flavor have high win percentscompared to non peanutalmond flavors__

# %%
candy_df['peanutyalmondy_present'] = candy_df['peanutyalmondy'].apply(lambda x: 'yes' if x == 1 else 'no')
candy_df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# 5                   Almond Joy          1       0        0               1
# 6                    Baby Ruth          1       0        1               1
# 7           Boston Baked Beans          0       0        0               1
# 8                   Candy Corn          0       0        0               0
# 9           Caramel Apple Pops          0       1        1               0
# 10             Charleston Chew          1       0        0               0
# ...

# %%
u1=candy_df.groupby('peanutyalmondy_present')
for group,values in u1:
    print("Peanutyalmondy_Presence: "+group)
    print(values.nlargest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Peanutyalmondy_Presence: no
#               competitorname  winpercent
# 79                      Twix   81.642914
# 28                   Kit Kat   76.768600
# 36                 Milky Way   73.099556
# 1               3 Musketeers   67.602936
# 68                 Starburst   67.037628
# 0                  100 Grand   66.971725
# 33                      M&Ms   66.574585
# 43             Nestle Crunch   66.470680
# 56                      Rolo   65.716286
# 38  Milky Way Simply Caramel   64.353340
# ------
# Peanutyalmondy_Presence: yes
#                 competitorname  winpercent
# 52    Reeses Peanut Butter cup   84.180290
# 51           Reeses Miniatures   81.866257
# 64                    Snickers   76.673782
# 53               Reeses pieces   73.434990
# 54  Reeses stuffed with pieces   72.887901
# 32          Peanut butter M&Ms   71.465050
# 42         Nestle Butterfinger   70.735641
# 47                 Peanut M&Ms   69.483788
# 65            Snickers Crisper   59.529251
# ...

# %% [markdown]
# Here if we observe, __top 3 candies that have peanutyalmondy flavor are Reeses Peanut Butter cup, Reeses Miniatures, Twix candies and these flavored candies have high winpercent compared to non flavored candies__

# %%
u2=candy_df.groupby('peanutyalmondy_present')
for group,values in u2:
    print("Peanutyalmondy_Presence: "+group)
    print(values.nsmallest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Peanutyalmondy_Presence: no
#         competitorname  winpercent
# 44           Nik L Nip   22.445341
# 12            Chiclets   24.524988
# 72        Super Bubble   27.303865
# 26          Jawbusters   28.127439
# 57   Root Beer Barrels   29.703691
# 71         Sugar Daddy   32.230995
# 2             One dime   32.261086
# 70        Sugar Babies   33.437550
# 19   Haribo Happy Cola   34.158958
# 9   Caramel Apple Pops   34.517681
# ------
# Peanutyalmondy_Presence: yes
#                 competitorname  winpercent
# 7           Boston Baked Beans   23.417824
# 46                      Payday   46.296597
# 5                   Almond Joy   50.347546
# 40                 Mr Good Bar   54.526451
# 6                    Baby Ruth   56.914547
# 65            Snickers Crisper   59.529251
# 47                 Peanut M&Ms   69.483788
# 42         Nestle Butterfinger   70.735641
# 32          Peanut butter M&Ms   71.465050
# 54  Reeses stuffed with pieces   72.887901
# ------

# %% [markdown]
# Here if we observe, __non peasnutyflavored candies have low winperccents and candies containing this flavor high winpercent almost starting from 40__

# %% [markdown]
# ### 4.6.1 PeanutyAlmondy Candies Vs Sugarpercent

# %%
sns.swarmplot(x="peanutyalmondy",y="sugarpercent",palette="YlOrBr",data=candy_df,linewidth=1).set_title('PeanutyAlmondy Candies Vs Sugarpercent',color="purple")
# Out:
# Text(0.5,1,'PeanutyAlmondy Candies Vs Sugarpercent')

# %% [markdown]
# Here,from above swarmplot, we can say that __Peanutyalmondy flavored candies have sugarpercent a slight above mean and in non flavored candies, they contain all amounts of sugarpercents__

# %% [markdown]
# ### 4.6.2 PeanutyAlmondy Candies Vs Price Percent

# %%
sns.violinplot(x="peanutyalmondy",y="pricepercent",data=candy_df,palette="vlag",linewidth=2).set_title("PeanutyAlmondy Candies Vs Price Percent", color="purple")
# Out:
# Text(0.5,1,'PeanutyAlmondy Candies Vs Price Percent')

# %% [markdown]
# Here, from above violinplot, we can say that __flavored candies price varied slightly above mean  from 0.6-0.8 and non flavored candies have outliers that is few non flavored peanutyalmondy candies have high price percents__

# %% [markdown]
# ### 4.6.3 Peanuty Candies Vs Other features

# %%
sns.pairplot(candy_df, hue="peanutyalmondy",x_vars=["chocolate","fruity","caramel"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="gnuplot")

# %% [markdown]
# From above pairplot, we can note the following:
#
#    1. For Chocolate-Peanutyalmondy combination,both flavored chocolates have high win percents, only peanutyalmondy also have almost high winpercent(Reg lines are upwards-positive)
#    2. For Fruity-Peanutyalmondy combination,peanutyalmondy flavored candies high above 60 winpercent and do not conttain fruity flavor in them(straight line)and there are no peanutyflavored candies with fruity flavors(mixed combination candies are absent-Reg lines are downwards)
#    3. For Caramel-Penutyalmondy combination,peanutyalmondy flavored candies high above 60 winpercent and do not conttain fruity flavor in them(straight line)and caramel candies have winpercents growing without peanutyalmondy flavor(reg line moves upwards)

# %%
sns.pairplot(candy_df, hue="peanutyalmondy",x_vars=["nougat","crispedricewafer","hard"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="hot")

# %% [markdown]
# From above pairplot, we note the following:
#
#    1.For Nougat-Peanutyalmondy combination, peanuty candies without nougat flavor have above 60 winpercents and combination of both flavors winpercent decreases(reg line moves downwards) and only nougat candies winpercent slowly increases(reg line moves upwards)
#    2. For Crispedricewafer-Peanutyalmondy combination, peanuty candies without crispedricewafer flavor have above 60 winpercents and combination of both flavors winpercent decreases(reg line moves downwards) and only crispedricewafer candies winpercent slowly increases towards 60(reg line moves upwards)
#    3. For Hard- Peanutyalmondy combination,not hard candies mixed with peanutyalmondy flavor have high winpercents that means people are liking to have soft peanutyalmondy candies more(straight regression line) and hard candies do not have peanutyalmondy flavor and reg line gradually moves downwards

# %%
sns.pairplot(candy_df, hue="peanutyalmondy",x_vars=["bar","pluribus"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="prism")

# %% [markdown]
# From above pariplot, we can note the following:
#    1. For Bar-Peanutyalmondy combination, non bar and peanuty flavor candies have high winpercents, as bar increases even though it has peanutyalmond flavor, people are dislking taste, reg line gradually moving downwards and without peanutyalmondy flavor, bar candies winpercent is growing(reg line moving upwards)
#    2. For Pluribus-Peanutyalmondy combination, non peanut flavor candies are not among other candies in the bag/box , they are one among the bags and winpercent gradyally decreases(reg line moving downwards) and peanutyalmondy flavored candies that are not among one box/bag have high winpercents but they also gradually decrease by winpercents(reg line moving downwards)

# %% [markdown]
# ### 4.7.0 Nougat Candies Vs WinPercent

# %%
sns.boxplot(x="nougat",y="winpercent",data=candy_df,palette="inferno").set_title("Nougat Candies Vs WinPercent",color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs WinPercent')

# %% [markdown]
# Here, from above box plot, we can say that __almost high winpercents are there for nougat flavored candies and non nougat flavored candies also have high winpercent__

# %%
candy_df['nougat_present'] = candy_df['nougat'].apply(lambda x: 'yes' if x == 1 else 'no')
candy_df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# 5                   Almond Joy          1       0        0               1
# 6                    Baby Ruth          1       0        1               1
# 7           Boston Baked Beans          0       0        0               1
# 8                   Candy Corn          0       0        0               0
# 9           Caramel Apple Pops          0       1        1               0
# 10             Charleston Chew          1       0        0               0
# ...

# %%
v1=candy_df.groupby('nougat_present')
for group,values in v1:
    print("Nougat_Presence: "+group)
    print(values.nlargest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Nougat_Presence: no
#                 competitorname  winpercent
# 52    Reeses Peanut Butter cup   84.180290
# 51           Reeses Miniatures   81.866257
# 79                        Twix   81.642914
# 28                     Kit Kat   76.768600
# 53               Reeses pieces   73.434990
# 54  Reeses stuffed with pieces   72.887901
# 32          Peanut butter M&Ms   71.465050
# 42         Nestle Butterfinger   70.735641
# 47                 Peanut M&Ms   69.483788
# 68                   Starburst   67.037628
# ------
# Nougat_Presence: yes
#         competitorname  winpercent
# 64            Snickers   76.673782
# 36           Milky Way   73.099556
# 1         3 Musketeers   67.602936
# 37  Milky Way Midnight   60.800701
# 6            Baby Ruth   56.914547
# 46              Payday   46.296597
# 10     Charleston Chew   38.975037
# ------

# %% [markdown]
# Here, if we observe __high win percent candies do not contain nougat in them and they are Reeses Peanut Butter cup,Reeses Miniatures, Twix and nougat flavored candies also have good winpercent range from 70-60

# %%
v2=candy_df.groupby('nougat_present')
for group,values in v2:
    print("Nougat_Presence: "+group)
    print(values.nsmallest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Nougat_Presence: no
#         competitorname  winpercent
# 44           Nik L Nip   22.445341
# 7   Boston Baked Beans   23.417824
# 12            Chiclets   24.524988
# 72        Super Bubble   27.303865
# 26          Jawbusters   28.127439
# 57   Root Beer Barrels   29.703691
# 71         Sugar Daddy   32.230995
# 2             One dime   32.261086
# 70        Sugar Babies   33.437550
# 19   Haribo Happy Cola   34.158958
# ------
# Nougat_Presence: yes
#         competitorname  winpercent
# 10     Charleston Chew   38.975037
# 46              Payday   46.296597
# 6            Baby Ruth   56.914547
# 37  Milky Way Midnight   60.800701
# 1         3 Musketeers   67.602936
# 36           Milky Way   73.099556
# 64            Snickers   76.673782
# ------

# %% [markdown]
# Here, if we observe __nougat presence/absence effects winpercent extremes that means it presence f nougat has winpercents between 30-70 range

# %% [markdown]
# ### 4.7.1 Nougat Candies Vs Sugar Percent

# %%
sns.swarmplot(x="nougat",y="sugarpercent",palette="gnuplot2",data=candy_df,linewidth=1).set_title('Nougat Candies Vs Sugarpercent',color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs Sugarpercent')

# %% [markdown]
# Here, from above swarm plot, we can say that __count of non nougat candies are more and they have all levels of sugarpercent whereas nougat candies have sugarpercent distributed around mean__

# %% [markdown]
# ### 4.7.2 Nougat Candies Vs Price Percent

# %%
sns.violinplot(x="nougat",y="pricepercent",data=candy_df,palette="cubehelix",linewidth=2).set_title("Nougat Candies Vs Price Percent", color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs Price Percent')

# %% [markdown]
# Here, from above violin plot, we can say that __price percent of nougat candies is nomralaly distributed or slightly around or higher than mean whereas non nougat candies have almost all levels of price percent__

# %% [markdown]
# ### 4.7.3 Nougat Candies vs Other features

# %%
sns.factorplot('nougat','winpercent', data=candy_df, hue='chocolate',palette="hot")
plt.title("Nougat Candies Vs Chocolate Candies", color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs Chocolate Candies')

# %% [markdown]
# From above factorplot, we can say that __these two are irrespective of each other, even presence/absence of nougat is not effecting chocolate winpercent__

# %%
sns.factorplot('nougat','winpercent', data=candy_df, hue='fruity',palette="bwr")
plt.title("Nougat Candies Vs Fruity Candies", color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs Fruity Candies')

# %% [markdown]
# Here from above factorplot, we can say that __there are no nougat candies with fruity flavor in them and nougat candies without fruity flavor have almost good winperents and non nougat candies with fruity flavor have mean winpercents__

# %%
sns.factorplot('nougat','winpercent', data=candy_df, hue='caramel',palette="gist_earth")
plt.title("Nougat Candies Vs Caramel Candies", color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs Caramel Candies')

# %% [markdown]
# Here,from above barplot, we can say that __caramael candies have high winpercents if they contain nougat in them or not and same in case of nougat candes have good winpercents as usual if they consists caramel or not__  that is __each feature here does not effect each other much__

# %%
sns.factorplot("nougat","winpercent",hue="peanutyalmondy",data=candy_df,palette="Reds")
plt.title("Nougat Candies Vs Peanutyalmondy Candies",color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs Peanutyalmondy Candies')

# %% [markdown]
# From above barplot,we can say that __irrespective of each other(peanutyalmondy,nougat), each have their own winpercents not effecting much of each other__

# %%
sns.factorplot("nougat","winpercent",hue="crispedricewafer",data=candy_df,palette="PiYG")
plt.title("Nougat Candies Vs crispedricewafer Candies", color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs crispedricewafer Candies')

# %% [markdown]
# From above plot, we can say that __Nougat candies do not have crispyredwafer in them and have good win percents whereas non nougat candies with crispyricedflavor have high winpecents__

# %%
sns.factorplot("nougat","winpercent",hue="hard",data=candy_df,palette="PuOr")
plt.title("Nougat Candies Vs Hard Candies", color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs Hard Candies')

# %% [markdown]
# From above plot, we can say that __nougat candies are not hard and people like to eat nougat flavored soft candies and so they have quite good winpercents whereas non nougat candies that are hard have less winpercent compared to non nougat non hard candies__

# %%
sns.factorplot("nougat","winpercent",hue="bar",data=candy_df,palette="Set1")
plt.title("Nougat Candies Vs Bar Candies", color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs Bar Candies')

# %% [markdown]
# From above barplot, we can say that __all nougat candies are Bar Candies and people like to eat bar candies, hence quite good winpercents whereas non nougat candies also which ar bar have high winpercents compared to non nougat no bar candies__

# %%
sns.factorplot("nougat","winpercent",hue="pluribus",data=candy_df,palette="Paired")
plt.title("Nougat Candies Vs Pluribus Candies", color="purple")
# Out:
# Text(0.5,1,'Nougat Candies Vs Pluribus Candies')

# %% [markdown]
# From above plot, we say that __all nougat candies are not one among box/bag and all non nougat candies which are one among other candies have mean winpercents__

# %% [markdown]
# ### 4.8.0 Crispedricewafer Candies Vs Winpercent

# %%
sns.boxplot(x="crispedricewafer",y="winpercent",data=candy_df,palette="PuBuGn").set_title("Crispedricewafer Candies Vs winpercent", color="purple")
# Out:
# Text(0.5,1,'Crispedricewafer Candies Vs winpercent')

# %% [markdown]
# Here, from above plot we can say that __winpercent of crispedricewafer ranges 60-70 and non crispedricewafer candies have outliers high winpercent__

# %%
candy_df['crispedricewafer_present'] = candy_df['crispedricewafer'].apply(lambda x: 'yes' if x == 1 else 'no')
candy_df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# 5                   Almond Joy          1       0        0               1
# 6                    Baby Ruth          1       0        1               1
# 7           Boston Baked Beans          0       0        0               1
# 8                   Candy Corn          0       0        0               0
# 9           Caramel Apple Pops          0       1        1               0
# 10             Charleston Chew          1       0        0               0
# ...

# %%
w1=candy_df.groupby('crispedricewafer_present')
for group,values in w1:
    print("Crispedricewafer_Presence: "+group)
    print(values.nlargest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Crispedricewafer_Presence: no
#                 competitorname  winpercent
# 52    Reeses Peanut Butter cup   84.180290
# 51           Reeses Miniatures   81.866257
# 64                    Snickers   76.673782
# 53               Reeses pieces   73.434990
# 36                   Milky Way   73.099556
# 54  Reeses stuffed with pieces   72.887901
# 32          Peanut butter M&Ms   71.465050
# 42         Nestle Butterfinger   70.735641
# 47                 Peanut M&Ms   69.483788
# 1                 3 Musketeers   67.602936
# ------
# Crispedricewafer_Presence: yes
#       competitorname  winpercent
# 79              Twix   81.642914
# 28           Kit Kat   76.768600
# 0          100 Grand   66.971725
# 43     Nestle Crunch   66.470680
# 23  Hersheys Krackel   62.284481
# 65  Snickers Crisper   59.529251
# 84          Whoppers   49.524113
# ------

# %% [markdown]
# Here, if you observe __even if Crispedricewafer flavored or non crispedricewafer flavored, the candies have quite good winpercents in range 60-80, top candies being Reeses Peanut Butter cup, Reeses Miniatures,Snickers,Twix candies__

# %%
w2=candy_df.groupby('crispedricewafer_present')
for group,values in w2:
    print("Crispedricewafer_Presence: "+group)
    print(values.nsmallest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Crispedricewafer_Presence: no
#         competitorname  winpercent
# 44           Nik L Nip   22.445341
# 7   Boston Baked Beans   23.417824
# 12            Chiclets   24.524988
# 72        Super Bubble   27.303865
# 26          Jawbusters   28.127439
# 57   Root Beer Barrels   29.703691
# 71         Sugar Daddy   32.230995
# 2             One dime   32.261086
# 70        Sugar Babies   33.437550
# 19   Haribo Happy Cola   34.158958
# ------
# Crispedricewafer_Presence: yes
#       competitorname  winpercent
# 84          Whoppers   49.524113
# 65  Snickers Crisper   59.529251
# 23  Hersheys Krackel   62.284481
# 43     Nestle Crunch   66.470680
# 0          100 Grand   66.971725
# 28           Kit Kat   76.768600
# 79              Twix   81.642914
# ------

# %% [markdown]
# Here if we observe,__absence of Crispedricewafer corressponds to low win percents whereas presence of crispedricewafer in candies have high winpercents__

# %% [markdown]
# ### 4.8.1 Crispedricewafer Candies Vs SugarPercent

# %%
sns.swarmplot(x="crispedricewafer",y="sugarpercent",palette="PuRd",data=candy_df,linewidth=1).set_title('Crispedricewafer Candies Vs Sugarpercent',color="purple")
# Out:
# Text(0.5,1,'Crispedricewafer Candies Vs Sugarpercent')

# %% [markdown]
# Here, from above plot we can say that __non crispedricewafer have all levels of sugarpercent in them and flavored candies have sugarpercent above mean__

# %% [markdown]
# ### 4.8.2 Crispedricewafer candies Vs Price percent

# %%
sns.violinplot(x="crispedricewafer",y="pricepercent",data=candy_df,palette="RdGy",linewidth=2).set_title("Crispedricewafer Candies Vs Price Percent", color="purple")
# Out:
# Text(0.5,1,'Crispedricewafer Candies Vs Price Percent')

# %% [markdown]
# From above plot, we can say that __flavored candies have high price percents and non flavored candies have all ranges of price percent from low to high__

# %% [markdown]
# ### 4.8.3 Crispedricewafer Candies Vs Other features

# %%
sns.barplot(x="crispedricewafer", y="winpercent",hue="chocolate",data=candy_df, palette = "Purples").set_title("Crispyricedwafer Candies Vs Chocolate Candies",color="purple")
# Out:
# Text(0.5,1,'Crispyricedwafer Candies Vs Chocolate Candies')

# %% [markdown]
# From above plot, we can say that __all chocolate candies have good win percent and does not contain crispyricewafer flavor in them and non flavored candies with chocolate flavor have high win percent than non flavored non chocolate candies__

# %%
sns.barplot(x="crispedricewafer", y="winpercent",hue="fruity",data=candy_df, palette = "Pastel2").set_title("Crispedricewafer Candies Vs Fruity Candies",color="purple")
# Out:
# Text(0.5,1,'Crispedricewafer Candies Vs Fruity Candies')

# %% [markdown]
# Here, from above plot we can say that __all crispedricewafer candies do not have fruity flavor in them and non flavored candies with fruity flavor have less win percents than compared to flavored candies with fruity flavor__

# %%
sns.barplot(x="crispedricewafer", y="winpercent",hue="caramel",data=candy_df, palette = "Greens").set_title("Crispyricedwafer Candies Vs Caramel Candies",color="purple")
# Out:
# Text(0.5,1,'Crispyricedwafer Candies Vs Caramel Candies')

# %% [markdown]
# here, if you observe __caramel and crispedricewafer are not effecting each other much__, they have their own winpercents

# %%
sns.barplot(x="crispedricewafer", y="winpercent",hue="peanutyalmondy",data=candy_df, palette = "Wistia").set_title("Crispyricedwafer Candies Vs Peanutyalmondy Candies",color="purple")
# Out:
# Text(0.5,1,'Crispyricedwafer Candies Vs Peanutyalmondy Candies')

# %% [markdown]
# Here, from above plot we can say that __individually each feaure has good win percents and when both flavored candies have good winpercent comared to absence of both flavors in the candies__

# %%
sns.barplot(x="crispedricewafer", y="winpercent",hue="nougat",data=candy_df, palette = "Oranges").set_title("Crispyricedwafer Candies Vs Nougat Candies",color="purple")
# Out:
# Text(0.5,1,'Crispyricedwafer Candies Vs Nougat Candies')

# %% [markdown]
# Here, from above  plot we can say that, __all crispedricewafer candies do not have nougat in them__ and they have good winpercents means people are liking only crispedricewafer candies and nougat candies without crispedricewafer also have quite good winpercent , this means __individually these flavoredd candies have good winpercents__

# %%
sns.barplot(x="crispedricewafer", y="winpercent",hue="hard",data=candy_df, palette = "afmhot").set_title("Crispyricedwafer Candies Vs Hard Candies",color="purple")
# Out:
# Text(0.5,1,'Crispyricedwafer Candies Vs Hard Candies')

# %% [markdown]
# From above plot, we can say that __all crispedricewafer candies are not hard and most liked by people thus contributing to high winpercnts whereas non crispedricewafer candies that are not hard also have quite good mean winpercents compared to non flavored hard candies__

# %%
sns.barplot(x="crispedricewafer", y="winpercent",hue="bar",data=candy_df, palette = "RdPu").set_title("Crispyricedwafer Candies Vs Bar Candies",color="purple")
# Out:
# Text(0.5,1,'Crispyricedwafer Candies Vs Bar Candies')

# %% [markdown]
# From above barplot, we can say that __people like to have bar candies more and if it is flavoredd , people tend to have even more contributing to high winpercents__ whereas __non bar candies combined with flavored have winpercents near to mean winpercent__

# %%
sns.barplot(x="crispedricewafer", y="winpercent",hue="pluribus",data=candy_df, palette = "PuOr").set_title("Crispyricedwafer Candies Vs Pluribus Candies",color="purple")
# Out:
# Text(0.5,1,'Crispyricedwafer Candies Vs Pluribus Candies')

# %% [markdown]
# Here, from above plot we can say that __pluribus candies that is not one among in box/bag and flavored candies have high winpercents and whereas non pluribus that is similar to other candies in bag if flavoreddor not flavored have winpercents close to mean winpercent__

# %% [markdown]
# ### 4.9.0 Hard Candies Vs Winpercent

# %%
sns.boxplot(x="hard",y="winpercent",data=candy_df,palette="CMRmap").set_title("Hard Candies Vs Winpercent",color="purple")
# Out:
# Text(0.5,1,'Hard Candies Vs Winpercent')

# %% [markdown]
# Here, from above box  plot, __it is crystal clear that non hard handies(soft candies)have high and above mean winpercents, whereas hard candies have below mean winpercent and one outlier is present in hard candy that has a good winpercent may be due to any other feature__

# %%
candy_df['hard_present'] = candy_df['hard'].apply(lambda x: 'yes' if x == 1 else 'no')
candy_df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# 5                   Almond Joy          1       0        0               1
# 6                    Baby Ruth          1       0        1               1
# 7           Boston Baked Beans          0       0        0               1
# 8                   Candy Corn          0       0        0               0
# 9           Caramel Apple Pops          0       1        1               0
# 10             Charleston Chew          1       0        0               0
# ...

# %%
x1=candy_df.groupby('hard_present')
for group,values in x1:
    print("Hard_Presence: "+group)
    print(values.nlargest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Hard_Presence: no
#                 competitorname  winpercent
# 52    Reeses Peanut Butter cup   84.180290
# 51           Reeses Miniatures   81.866257
# 79                        Twix   81.642914
# 28                     Kit Kat   76.768600
# 64                    Snickers   76.673782
# 53               Reeses pieces   73.434990
# 36                   Milky Way   73.099556
# 54  Reeses stuffed with pieces   72.887901
# 32          Peanut butter M&Ms   71.465050
# 42         Nestle Butterfinger   70.735641
# ------
# Hard_Presence: yes
#                competitorname  winpercent
# 41                      Nerds   55.354046
# 74                Tootsie Pop   48.982651
# 17                 Gobstopper   46.783348
# 63             Smarties candy   45.995827
# 58                      Runts   42.849144
# 83  Werthers Original Caramel   41.904308
# 49                  Pop Rocks   41.265511
# 14                   Dum Dums   39.460556
# 16                    Fun Dip   39.185505
# ...

# %% [markdown]
# Here, if we observe __no hard candies have high winpercents and they are Resses Peanut Buttercup, Reeses Miniatures, Twix candies and hard candies high winpercent waas 55.354046 that is just above mean winpercent__

# %%
x2=candy_df.groupby('hard_present')
for group,values in x2:
    print("hard_Presence: "+group)
    print(values.nsmallest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# hard_Presence: no
#         competitorname  winpercent
# 44           Nik L Nip   22.445341
# 7   Boston Baked Beans   23.417824
# 12            Chiclets   24.524988
# 72        Super Bubble   27.303865
# 71         Sugar Daddy   32.230995
# 2             One dime   32.261086
# 70        Sugar Babies   33.437550
# 19   Haribo Happy Cola   34.158958
# 9   Caramel Apple Pops   34.517681
# 59             Sixlets   34.722000
# ------
# hard_Presence: yes
#                competitorname  winpercent
# 26                 Jawbusters   28.127439
# 57          Root Beer Barrels   29.703691
# 69        Strawberry bon bons   34.578991
# 55                   Ring pop   35.290756
# 81                   Warheads   39.011898
# 30                  Lemonhead   39.141056
# 16                    Fun Dip   39.185505
# 14                   Dum Dums   39.460556
# 49                  Pop Rocks   41.265511
# 83  Werthers Original Caramel   41.904308
# ------

# %% [markdown]
# Here, if we obserrve __soft candies have low winpercents comapred to hard candies, may be candies have less winpercent effected by any other feature__ and soft least winpercent candies are __Nik L Nip,Bosten Baked Beans, Chiclets__

# %% [markdown]
# ### 4.9.1 Hard Candies Vs Sugar Percent

# %%
sns.swarmplot(x="hard",y="sugarpercent",palette="brg",data=candy_df,linewidth=1).set_title('Hard Candies Vs Sugarpercent',color="purple")
# Out:
# Text(0.5,1,'Hard Candies Vs Sugarpercent')

# %% [markdown]
# Here, from above plot we can say that __soft candies have all levels of sugarpercent in them and hard candies have low sugarpercents and above mean sugarpercents__

# %% [markdown]
# ### 4.9.2 Hard Candies Vs PricePercent

# %%
sns.violinplot(x="hard",y="pricepercent",data=candy_df,palette="bone",linewidth=2).set_title("Hard Candies Vs Price Percent", color="purple")
# Out:
# Text(0.5,1,'Hard Candies Vs Price Percent')

# %% [markdown]
# Here,from above plot,we observe, __soft candies have increasing pricepercents, hard candies have low pricepercents__

# %% [markdown]
# ### 4.9.3 Hard Candies Vs Other Features

# %%
sns.pairplot(candy_df, hue="hard",x_vars=["chocolate","fruity","caramel"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="copper")

# %% [markdown]
# From above pairplot, note the following
#
#
#   1. For Hard-chocolate candies combination, chocolate-non hard candies have high winpercents(reg lines moving upwards)
#      choclate-hard candies count is not much , even if present theyhave below mean winpercent
#      non chocolate-non hard candies also have quite good winpercent(reg line moving downwards)
#      non chocolate-hard candies have avg winpercents (reg line moving upwards)
#
#   2. For Fruity-Hard candies combination,
#      non fruity -non hard candies, they have high winpercents , but as it turn fruity and hard win percent                  decreases(reg line moving downwards)
#      fruity-non hard candies, candies also have quite good winpercents
#      non fruity-hard candies are less in count and have low minimum winpercents
#      fruity-hard candies have quite good around mean winpercents(reg line slowy moving upwards)
#
#   3. For Caramel-Hard candies combination,
#      caramel-non hard candies have high winpercents(reg line moving upwards)
#      non caramel-non hard candies also have high win percents
#      caramel-hard candies are very less in count, have minimum winpercent
#      non caramel-hard candies have around mean winpercents(reg line moving upwards)

# %%
sns.pairplot(candy_df, hue="hard",x_vars=["peanutyalmondy","nougat","crispedricewafer"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="gist_heat")

# %% [markdown]
# From above pairplot,it is easily understood that
#
# 1. For Non Hard(Soft) - Non peanutyalmondy,Peanutyalmondy,Non Nougat, Nougat, Non crispedricewafer, crispedrice wafer flavored candies combination have very good mean winpercents(reg lines moving upwards)
# 2. For Hard- Non peanutyalmondy,Peanutyalmondy,Non Nougat,Nougat, Non crispedricewafer, crispedrice wafer flavored candies combination flavored candies have minimum winpercents(reg linesare stratight)

# %%
sns.pairplot(candy_df, hue="hard",x_vars=["bar","pluribus"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="summer")

# %% [markdown]
# From above pairplot, we can note the following
#
#    1. For Non hard(soft)-Bar,No Bar candies combination, have high percents(reg line moving upwards)
#       Hard-No bar candies, have around mean winpercents(around 40-55)
#       Hard-Bar candies are less in count and have minimum winpercent(aroud 40, hard candies reg line is straight)
#    2. For Non Hard-pluribus, non pluribus candies combination have good winpercents but as it is one among other             candies(that is for Non Hard-Pluribus candy combination winpercent starts decreasing and hence reg lie moving         downwards)
#       For Hard- pluribus, non pluribus candies combination have below mean winpercents around 40(straight reg line)

# %% [markdown]
# ### 4.10.0 Bar Candies Vs Win Percent

# %%
sns.boxplot(x="bar",y="winpercent",data=candy_df,palette="hot").set_title("Bar Candies Vs Win Percent",color="purple")
# Out:
# Text(0.5,1,'Bar Candies Vs Win Percent')

# %% [markdown]
# From above box plot, __it is clear that bar candies have quite good win percents ranging from 40-80__ whereas __Non bar candies have winpercents ranging from 38-55 and two outliers are present for Non bar candies and they might have high win percent due to some other flavor like chocolate, no hard candies__

# %%
candy_df['bar_present']=candy_df['bar'].apply(lambda x: 'yes' if x == 1 else 'no')
candy_df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# 5                   Almond Joy          1       0        0               1
# 6                    Baby Ruth          1       0        1               1
# 7           Boston Baked Beans          0       0        0               1
# 8                   Candy Corn          0       0        0               0
# 9           Caramel Apple Pops          0       1        1               0
# 10             Charleston Chew          1       0        0               0
# ...

# %%
y1=candy_df.groupby('bar_present')
for group,values in y1:
    print("Bar_Presence: "+group)
    print(values.nlargest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Bar_Presence: no
#                 competitorname  winpercent
# 52    Reeses Peanut Butter cup   84.180290
# 51           Reeses Miniatures   81.866257
# 53               Reeses pieces   73.434990
# 54  Reeses stuffed with pieces   72.887901
# 32          Peanut butter M&Ms   71.465050
# 47                 Peanut M&Ms   69.483788
# 68                   Starburst   67.037628
# 33                        M&Ms   66.574585
# 56                        Rolo   65.716286
# 60           Skittles original   63.085140
# ------
# Bar_Presence: yes
#               competitorname  winpercent
# 79                      Twix   81.642914
# 28                   Kit Kat   76.768600
# 64                  Snickers   76.673782
# 36                 Milky Way   73.099556
# 42       Nestle Butterfinger   70.735641
# 1               3 Musketeers   67.602936
# 0                  100 Grand   66.971725
# 43             Nestle Crunch   66.470680
# 38  Milky Way Simply Caramel   64.353340
# ...

# %% [markdown]
# Here, if we observe two outliers mentioned in boxplot are __Reeses Peanut Butter cup, Reeses Miniatures__ candies, both __bar and non bar have good win percents but non bar have high range__

# %%
y2=candy_df.groupby('bar_present')
for group,values in y2:
    print("Bar_Presence: "+group)
    print(values.nsmallest(10,'winpercent')[['competitorname','winpercent']])
    print('------')
# Out:
# Bar_Presence: no
#         competitorname  winpercent
# 44           Nik L Nip   22.445341
# 7   Boston Baked Beans   23.417824
# 12            Chiclets   24.524988
# 72        Super Bubble   27.303865
# 26          Jawbusters   28.127439
# 57   Root Beer Barrels   29.703691
# 71         Sugar Daddy   32.230995
# 2             One dime   32.261086
# 70        Sugar Babies   33.437550
# 19   Haribo Happy Cola   34.158958
# ------
# Bar_Presence: yes
#              competitorname  winpercent
# 10          Charleston Chew   38.975037
# 46                   Payday   46.296597
# 39                   Mounds   47.829754
# 77  Tootsie Roll Snack Bars   49.653503
# 5                Almond Joy   50.347546
# 40              Mr Good Bar   54.526451
# 24  Hersheys Milk Chocolate   56.490501
# 6                 Baby Ruth   56.914547
# 25    Hersheys Special Dark   59.236122
# 65         Snickers Crisper   59.529251
# ------

# %% [markdown]
# Here if we observe, __non bar candies have very less win percent compared to bar candies means people usually picked bar candies to taste__

# %% [markdown]
# ### 4.10.1 Bar Candies Vs Sugarpercent

# %%
sns.scatterplot(x="bar",y="sugarpercent",palette="gist_rainbow",data=candy_df,linewidth=1).set_title('Bar Candies Vs Sugarpercent',color="purple")
# Out:
# Text(0.5,1,'Bar Candies Vs Sugarpercent')

# %% [markdown]
# Here, if we observe above scatter plot, we can say that __non bar candies have all levels of sugarpercent in them and bar candies  have sugarpercent mostly concentrated above mean sugarpercent__

# %% [markdown]
# ### 4.10.2 Bar Candies Vs Price Percent

# %%
sns.violinplot(x="bar",y="pricepercent",data=candy_df,palette="gist_yarg",linewidth=2).set_title("Bar Candies Vs Price Percent", color="purple")
# Out:
# Text(0.5,1,'Bar Candies Vs Price Percent')

# %% [markdown]
# Here, if we observe above violin plot, we can notice that __pricepercent range is also high in non bar candies whereas bar candies mostly have price percent between 0.8 and 1.0__

# %% [markdown]
# ### 4.10.3 Bar Candies Vs Other features

# %%
sns.pairplot(candy_df, hue="bar",x_vars=["chocolate","fruity","caramel"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="gist_ncar")

# %% [markdown]
# From above paiplot, we can note the following:
#
#   1. For chocolate-bar candies, have high win percent(reg line moving upwards)
#      chocolate-non bar candies also have high winpercents(reg line moving upwards)
#      There are no non chocolate non bar candies means all chocolate candies are bar in nature
#      All non chocolate flavor candies are not bar candies means they might be small candies and they also have good          winpercents
#
#   2. For fruity-bar candies combination, all fruity candies are not bar candies and have winpercents around 70
#      Non fruity-Non bar candies winpercent concentration slightly decreases(hence, reg line moving downwards)
#      Non fruit canadies are bar in nature and have good win percents ranging from 40-80 (reg line is stratight)
#
#   3. For caramel-bar candies, have high win percents(reg line red line moving upwards)
#      caramel-non bar candies have minimmal winpercents(reg line green line moving downwards)
#      non caramel-non bar candies  have winpercents in high range(have high and low winpercents)
#      non caramel-bar candies  have winpercents ranaging from 50-80(reg line red moving upwards)

# %%
sns.pairplot(candy_df, hue="bar",x_vars=["peanutyalmondy","nougat","crispedricewafer"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="terrain")

# %% [markdown]
# From above pairplot, we can note the following
#
#    1. For peanutyalmondy-bar candies have mean winpercents, non peanutyalmondy-bar candies have high winpercents(hence       reg maron line moving downwards)
#       non peanutyalmondy-non bar candies, bar candies have growing winpercents(hence reg green line moving upwards)
#       This means that peanutyalmondy flavoredd candies mostly are not bar natured candies but even they are not bar           they have quite godd winpercents may be people are liking its taste even if they are bar or not bar candies
#
#    2. For Nougat-bar, all nougat flavored candies are bar in nature have good win percents
#       Non Nougat-bar candies  also have good win percents(reg line moving upwards)
#       This may mean people are liking both nougat flavor and bar natured candies
#       For non nougat candies are mostly not bar candies , still they have high winpercent range may be due to nougat         flavor
#       Nougat Non bar candies are not there so no reg green line
#
#    3. For crispedricewafer,non crispricewafer-bar candies, have growing win percents(red reg line moving upwards)
#       Non crispedriewafer non bar candies also have high winpercents may be due to other features
#       Crispedricewafer -non bar candies have growing mean winpercent(reg green line moving upwards)

# %%
sns.pairplot(candy_df, hue="bar",x_vars=["hard","pluribus"],y_vars="winpercent",height=3.5,kind="reg",markers="+",palette="plasma")

# %% [markdown]
# From above pairplot, we can note the following
#
#    1. For hard-non bar candies, low win percents ranging from 28-55(all hard bars are nor bars)
#       This means not much people like hard and non bar candies(reg violet line moving downwards)
#       Non hard-non bar candies have few outlier but may be due to some other feature but winpercent is gradullay             decreasing
#       Non Hard (soft) candies are more in count and most of them are having good win percents(red straight reg line)
#       There are no hard bar candies , all are small hard candies
#
#    2. For pluribus-non bar candies,  all not one among other candies are not bar candies and have good winpercents           (straight violet line)
#       non pluribus-non bar candies also have better winpercents(outliers are present)
#       There are no plurius-bar candies
#       Pluribus-bar candies have good winpercents means one among other candies in the bag/box are bar candies(straight       red reg line)

# %% [markdown]
# ## 5.0 Understanding Correlations among variables/features

# %% [markdown]
# - The diagonal of the above matirx shows the auto-correlation of the variables.
#
# - correlations can vary from -1 to +1. Closer to +1 means strong positive correlation and close -1 means strong negative correlation. Closer to 0 means not very strongly correlated. variables with __strong correlations__ are mostly probably candidates for __model builing__.

# %%
features_correlation = candy_df.corr()
plt.figure(figsize=(8,8))
sns.heatmap(features_correlation,vmax=1,square=True,annot=True,cmap='Reds',linecolor="black",linewidth=.01)
plt.title('Correlation between features')
plt.show()

# %% [markdown]
# From above correlation heatmap, we can note the following correlated variables:
#
#    1. __chocolate-peanutyalmondy__
#    2. __chocolate-caramel__
#    3. __chocolate-nougat__
#    4. __chocolate-crispedricewafer__
#    5. __chocolate-bar__
#    6. __chocolate-pricepercent__
#    7. __chocolate-winpercent__
#    8. __fruity-hard__
#    9. __fruity-pluribus__
#    10. __caramel-nougat__
#    11. __caramel- bar__
#    12. __caramel-pricepercent__
#    13. __peanutyalmondy-winpercent__
#    14. __peanutyalmondy-bar__
#    15. __peanutyalmondy-pricepercent__
#    16. __nougat-bar__
#    17. __crispyricedwafer-bar__
#    18. __crispyricedwafer-winpercent__
#    19. __crispyricedwafer-pricepercent__
#    20. __caramel-bar__
#    21. __bar-nougat__
#    22. __bar-pricepercent__
#    23. __bar-winpercent__
#    24. __sugarpercent-pricepercent__
#    25. __sugarpercent-caramel__
#    26. __pricepercent-winpercent__

# %% [markdown]
# ## 6.0 Model Building

# %% [markdown]
# Here, from above EDA I understood that out target variable is winpercent(how many people are like to have which type of candy), to predict winpercent of candy since it is continuous numeric variable, we will now build model using Predictive Modelling Technique called __Regression__, then we build model using __Linear Regression, Multiple Linear Regression__(since many other features are trying to have effect on winpercent)

# %% [markdown]
# ### 6.1.0 Preparing x and y using pandas

# %%
feature_cols = ['chocolate', 'fruity','caramel','peanutyalmondy','nougat','crispedricewafer','hard','bar','pluribus']                # create a Python list of feature names
X = candy_df[feature_cols]                                     # use the list to select a subset of the original DataFrame-+

# %%
print(type(X))
print(X.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (85, 9)

# %%
feature_cols = ['chocolate', 'fruity','caramel','peanutyalmondy','nougat','crispedricewafer','hard','bar','pluribus']                # create a Python list of feature names
X = candy_df[feature_cols]                                     # use the list to select a subset of the original DataFrame-+

# %%
y=candy_df.winpercent
y.head()
# Out:
# 0    66.971725
# 1    67.602936
# 2    32.261086
# 3    46.116505
# 4    52.341465
# Name: winpercent, dtype: float64

# %%
print(type(y))
print(y.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (85,)

# %% [markdown]
# ### 6.1.1 Splitting X and Y into training and test datasets.

# %%
from sklearn.cross_validation import train_test_split

def split(X,y):
    return train_test_split(X, y, test_size=0.20, random_state=1)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X_train, X_test, y_train, y_test=split(X,y)
print('Train cases as below')
print('X_train shape: ',X_train.shape)
print('y_train shape: ',y_train.shape)
print('\nTest cases as below')
print('X_test shape: ',X_test.shape)
print('y_test shape: ',y_test.shape)
# Out:
# Train cases as below
# X_train shape:  (68, 9)
# y_train shape:  (68,)
#
# Test cases as below
# X_test shape:  (17, 9)
# y_test shape:  (17,)

# %% [markdown]
# ### 6.1.2 Linear regression in scikit-learn

# %%
def linear_reg( X, y, gridsearch = False):
    
    X_train, X_test, y_train, y_test = split(X,y)
    
    from sklearn.linear_model import LinearRegression
    linreg = LinearRegression()
    
    if not(gridsearch):
        linreg.fit(X_train, y_train) 

    else:
        from sklearn.model_selection import GridSearchCV
        parameters = {'normalize':[True,False], 'copy_X':[True, False]}
        linreg = GridSearchCV(linreg,parameters, cv = 10,refit = True)
        linreg.fit(X_train, y_train)                                                           # fit the model to the training data (learn the coefficients)
        
        print("Mean cross-validated score of the best_estimator : ", linreg.best_score_)  
        
        y_pred_test = linreg.predict(X_test)                                                   # make predictions on the testing set

        
        RMSE_test = (metrics.mean_squared_error(y_test, y_pred_test))                          # compute the RMSE of our predictions
        
        print('RMSE for the test set is {}'.format(RMSE_test))

    return linreg

# %% [markdown]
# ### LR without GridSearchCV

# %%
X = candy_df[feature_cols]  
y = candy_df.winpercent
linreg = linear_reg(X,y)

# %% [markdown]
# ### Interpreting Model Coefficients

# %%
print('Intercept:',linreg.intercept_)          # print the intercept 
print('Coefficients:',linreg.coef_)
# Out:
# Intercept: 37.34589216040869
# Coefficients: [19.01721881  8.97118296 -2.22747853  9.87628002  8.44845764 15.98888327
#  -5.30714785 -3.93969314 -1.35114732]

# %% [markdown]
# __Here, to understand which feature column is contributing how much, we zip the coefficients and intercept__

# %%
feature_cols.insert(0,'Intercept')
coef = linreg.coef_.tolist()            
coef.insert(0, linreg.intercept_)

# %%
eq1 = zip(feature_cols, coef)

for c1,c2 in eq1:
    print(c1,c2)
# Out:
# Intercept 37.34589216040869
# chocolate 19.017218808695127
# fruity 8.97118295761156
# caramel -2.227478528768793
# peanutyalmondy 9.876280016868542
# nougat 8.448457641168675
# crispedricewafer 15.988883267195819
# hard -5.307147846979772
# bar -3.939693141393328
# pluribus -1.3511473234378262

# %% [markdown]
# __y = 37.345 + 19.017 `*` chocolate + 8.971 `*` fruity + -2.227 `*` caramel + 9.876 `*`  peanutyalmondy + 8.448 `*` nougat + 15.988 `*` crispedricewafer + -5.307 `*` hard + -3.939 `*` bar + -1.351 `*` pluribus__

# %% [markdown]
# How do we interpret the chocolate coefficient (_19.017_)
# - A "unit" increase in chocolate candy is **associated with** a _"19.017_ unit" increase in winpercent.
# - Or more clearly: An additional $1,000 winpercent of candy is **associated with** an increase in 190.17 units of chocolate flavor in candy__.
#
# Important Notes:
# - This is a statement of __association__, not __causation__.
# - If an increase in chocolate flavor was associated with a __decrease__ in winpercent,  β1  would be __negative.__
# -In such a case, __hard,bar,pluribus__ candies have __very low winpercents__
# -Here, __caramel,hard ,bar,pluribus__ have negative coefficients and so we run model by dropping those features in building model doing Feature Selection

# %% [markdown]
# ### 6.1.4 Using the Model for Prediction

# %%
y_pred_train = linreg.predict(X_train)

# %%
y_pred_test = linreg.predict(X_test)

# %%
linreg.predict([[0,0,0,0,0,0,1,1,0]])
# Out:
# array([28.09905117])

# %% [markdown]
# Here if we observe, I placed __1 for hard,bar presence__ in candies that contributed __very less winpercent__

# %%
linreg.predict([[0,0,0,0,0,0,1,1,1]])
# Out:
# array([26.74790385])

# %% [markdown]
# Here if we observe, I placed __1 for hard,bar,pluribus presence,__ in candies that contributed __very less winpercent__

# %%
linreg.predict([[0,0,1,0,0,0,1,1,1]])
# Out:
# array([24.52042532])

# %% [markdown]
# Here if we observe, I placed __1 for hard,bar,pluribus,caramel presence,__ in candies that contributed __very less winpercent__

# %% [markdown]
# Here, actually in above three cells , __model is predicted against combination of less coefficients flavors and we observe they contribute very less winpercents and which give insight to drop those features__

# %%
linreg.predict([[0,0,0,0,0,0,0,0,1]])
# Out:
# array([35.99474484])

# %% [markdown]
# Here, from above __model is predicted against individual flavor contribution of winpercents and we observe caramel,hard,bar,pluribus candies have low winpercents range between 30-35__

# %%
linreg.predict([[0,1,0,1,1,1,1,1,1]])
# Out:
# array([70.03270773])

# %% [markdown]
# Here, from above we predicted __model against different combinations and got winpercents around 55-80__

# %% [markdown]
# We need an evaluation metric in order to compare our predictions with the actual values.

# %% [markdown]
# ### 6.1.5 Model Evaluation using Metrics

# %% [markdown]
# #### 6.1.5.0 Mean absolute Error

# %% [markdown]
# __Mean Absolute Error__ (MAE) is the mean of the absolute value of the errors:
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
# Computing the MAE for our winpercent predictions

# %%
from sklearn import metrics

# %%
MAE_train = metrics.mean_absolute_error(y_train, y_pred_train)
MAE_test = metrics.mean_absolute_error(y_test, y_pred_test)

# %%
print('MAE for training set is {}'.format(MAE_train))
print('MAE for test set is {}'.format(MAE_test))
# Out:
# MAE for training set is 7.9104184999437415
# MAE for test set is 10.058487015379015

# %% [markdown]
# #### 6.1.5.1 Mean Squared Error

# %% [markdown]
# __Mean Squared Error__ (MSE) is the mean of the squared errors:
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# Computing the MSE for our winpercent predictions

# %%
MSE_train = metrics.mean_squared_error(y_train, y_pred_train)
MSE_test = metrics.mean_squared_error(y_test, y_pred_test)

# %%
print('MSE for training set is {}'.format(MSE_train))
print('MSE for test set is {}'.format(MSE_test))
# Out:
# MSE for training set is 98.69692426101362
# MSE for test set is 150.13487201193936

# %% [markdown]
# #### 6.1.5.2 Root Mean Squared Error

# %% [markdown]
# __Root Mean Squared Error__ (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Computing the RMSE for our winpercent predictions

# %%
RMSE_train = np.sqrt( metrics.mean_squared_error(y_train, y_pred_train))
RMSE_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test))

# %%
print('RMSE for training set is {}'.format(RMSE_train))
print('RMSE for test set is {}'.format(RMSE_test))
# Out:
# RMSE for training set is 9.934632567992317
# RMSE for test set is 12.252953603598577

# %% [markdown]
# Comparing these metrics:
#
# - __MAE__ is the easiest to understand, because it's the __average error.__
# - __MSE__ is more popular than MAE, because MSE "punishes" larger errors.
# - __RMSE__ is even more popular than MSE, because RMSE is _interpretable_ in the "y" units.
#     - Easier to put in context as it's the same units as our response variable.

# %% [markdown]
# ### 6.1.6 Model Evaluation using Rsquared value.

# %%
yhat = linreg.predict(X_train)
SS_Residual = sum((y_train-yhat)**2)
SS_Total = sum((y_train-np.mean(y_train))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
print(r_squared, adjusted_r_squared)
# Out:
# 0.5465244553896056 0.47615756053626856

# %%
yhat = linreg.predict(X_test)
SS_Residual = sum((y_test-yhat)**2)
SS_Total = sum((y_test-np.mean(y_test))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print(r_squared, adjusted_r_squared)
# Out:
# 0.24613982535072598 -0.723108970626912

# %% [markdown]
# ## 7. Feature Selection
#
# At times some features do not contribute much to the accuracy of the model, in that case its better to discard those features.<br/>
# - Let's check whether __"hard","bar","pluribus","caramel","crispedricewafer"__ to improve the quality of our winpercent predictions.<br/>
# To check this we are going to take all the features other than above features and see if the error (RMSE) is reducing or not.
# - Also Applying __Gridsearch__ method for exhaustive search over specified parameter values of  estimator.

# %%
feature_cols = ['chocolate','fruity','peanutyalmondy','nougat']             # create a Python list of feature names
X = candy_df[feature_cols]

# %%
print(type(X))
print(X.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (85, 4)

# %%
y=candy_df.winpercent
y.head()
# Out:
# 0    66.971725
# 1    67.602936
# 2    32.261086
# 3    46.116505
# 4    52.341465
# Name: winpercent, dtype: float64

# %%
print(type(y))
print(y.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (85,)

# %% [markdown]
# ### 7.1 Splitting X and Y into training and test datasets.

# %%
from sklearn.cross_validation import train_test_split

def split(X,y):
    return train_test_split(X, y, test_size=0.20, random_state=1)

# %%
X_train, X_test, y_train, y_test=split(X,y)
print('Train cases as below')
print('X_train shape: ',X_train.shape)
print('y_train shape: ',y_train.shape)
print('\nTest cases as below')
print('X_test shape: ',X_test.shape)
print('y_test shape: ',y_test.shape)
# Out:
# Train cases as below
# X_train shape:  (68, 4)
# y_train shape:  (68,)
#
# Test cases as below
# X_test shape:  (17, 4)
# y_test shape:  (17,)

# %% [markdown]
# ### 7.2 Linear regression in scikit-learn

# %%
def linear_reg( X, y, gridsearch = False):
    
    X_train, X_test, y_train, y_test = split(X,y)
    
    from sklearn.linear_model import LinearRegression
    linreg = LinearRegression()
    
    if not(gridsearch):
        linreg.fit(X_train, y_train) 

    else:
        from sklearn.model_selection import GridSearchCV
        parameters = {'normalize':[True,False], 'copy_X':[True, False]}
        linreg = GridSearchCV(linreg,parameters, cv = 10,refit = True)
        linreg.fit(X_train, y_train)                                                           # fit the model to the training data (learn the coefficients)
        
        print("Mean cross-validated score of the best_estimator : ", linreg.best_score_)  
        
        y_pred_test = linreg.predict(X_test)                                                   # make predictions on the testing set

        
        RMSE_test = (metrics.mean_squared_error(y_test, y_pred_test))                          # compute the RMSE of our predictions
        
        print('RMSE for the test set is {}'.format(RMSE_test))

    return linreg

# %% [markdown]
# ### LR without GridSearchCV

# %%
X = candy_df[feature_cols]  
y = candy_df.winpercent
linreg = linear_reg(X,y)

# %% [markdown]
# ### 7.3 Interpreting Model Coefficients

# %%
print('Intercept:',linreg.intercept_)          # print the intercept 
print('Coefficients:',linreg.coef_)
# Out:
# Intercept: 35.607940093559634
# Coefficients: [21.84791181  7.96227707  9.04997506  3.14145802]

# %% [markdown]
# __Here, to understand which feature column is contributing how much, we zip the coefficients and intercept__

# %%
feature_cols.insert(0,'Intercept')
coef = linreg.coef_.tolist()            
coef.insert(0, linreg.intercept_)

# %%
eq1 = zip(feature_cols, coef)

for c1,c2 in eq1:
    print(c1,c2)
# Out:
# Intercept 35.607940093559634
# chocolate 21.84791181202078
# fruity 7.962277073794528
# peanutyalmondy 9.049975057510325
# nougat 3.1414580223175412

# %% [markdown]
# __y = 35.607 + 21.847 `*` chocolate + 7.962 `*` fruity +  9.049 `*`  peanutyalmondy + 3.141 `*` nougat__

# %% [markdown]
# ### 7.4 Using the Model for Prediction

# %%
y_pred_train = linreg.predict(X_train)

# %%
y_pred_test = linreg.predict(X_test)

# %%
linreg.predict([[1,1,1,1]])
# Out:
# array([77.60956206])

# %% [markdown]
# Here, __winpercent of all four flavored candies is 77__

# %% [markdown]
# ### 7.5 Model Evaluation using Metrics

# %% [markdown]
# #### 7.5.0 Mean absolute Error

# %%
from sklearn import metrics

# %%
MAE_train = metrics.mean_absolute_error(y_train, y_pred_train)
MAE_test = metrics.mean_absolute_error(y_test, y_pred_test)

# %%
print('MAE for training set is {}'.format(MAE_train))
print('MAE for test set is {}'.format(MAE_test))
# Out:
# MAE for training set is 8.539506311320745
# MAE for test set is 8.384054813685049

# %% [markdown]
# #### 7.5.1 Mean Squared Error

# %%
MSE_train = metrics.mean_squared_error(y_train, y_pred_train)
MSE_test = metrics.mean_squared_error(y_test, y_pred_test)

# %%
print('MSE for training set is {}'.format(MSE_train))
print('MSE for test set is {}'.format(MSE_test))
# Out:
# MSE for training set is 114.45579796423844
# MSE for test set is 111.65030774547162

# %% [markdown]
# #### 7.5.2 Root Mean Squared Error

# %%
RMSE_train = np.sqrt( metrics.mean_squared_error(y_train, y_pred_train))
RMSE_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test))

# %%
print('RMSE for training set is {}'.format(RMSE_train))
print('RMSE for test set is {}'.format(RMSE_test))
# Out:
# RMSE for training set is 10.698401654650961
# RMSE for test set is 10.566470922000004

# %% [markdown]
# #### 7.5.3  Model Evaluation using Rsquared value.

# %%
yhat = linreg.predict(X_train)
SS_Residual = sum((y_train-yhat)**2)
SS_Total = sum((y_train-np.mean(y_train))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
print(r_squared, adjusted_r_squared)
# Out:
# 0.47411831012699046 0.44072899648425967

# %%
yhat = linreg.predict(X_test)
SS_Residual = sum((y_test-yhat)**2)
SS_Total = sum((y_test-np.mean(y_test))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print(r_squared, adjusted_r_squared)
# Out:
# 0.4393792769880075 0.2525057026506766

# %% [markdown]
# - _Before_ doing feature selection _RMSE_ for the test dataset was __12.252__.<br/>
# - _After_ discarding 'hard','bar','caramel','pluribus','crispedricewafer' column, RMSE comes to be __10.566__.<br/>
# As you can see there is __significant improvement__ in the quality, therefore, the above columns should be discarded. But if in some other case if there is no significant decrease in the RMSE, then you must keep that feature.

# %% [markdown]
# ## 8. Conclusions

# %% [markdown]
# 1. Almost count of non flavored candies is more when countplot is plotted for each single feature/flavor
# 2. Studied Numerical Variable Distribution Trends
#       - Winpercent: Distribution Curve is __left skewed__, many of candies have winpercent less than mean winpercent                       50.30
#       - Pricepercent: Distribution Curve is __normal__, all candies have varying pricepercents
#       - Sugarpercent: Distribution Curve is __normal__, all candies have varying sugarpercents
# 3. Sugarpercent is __slightly increasing__ per pricepercent(reference is scatter plot)
# 4. Top winpercent candies having high winpercent __84.180,81.866__ are __Reeses Peanut Butter, Reeses Miniature__ contain    following flavors
#       - __chocolate, caramel,peanutyalmondy,not hard, not bar__ candies
# 5. Least winpercent candies 22.44,23.41 are __Nik L Nip,Boston Baked Beans__ have following flavors
#       - __fruity,pluribus,peanutyalmondy__
# 6. __chocolate, fuity, peanutyalmondy, nougat__ are Independent variables contributing to good winpercents
# 7. Following are correlated variables having good winpercents(combined flavors liked by people)
#       - Peanutyalmondy-Non bar candies combination mostly liked by people
#       - chocolate-non hard candies combination mostly liked by people
#       - crispedricewafer-caramel candies combination mostly liked by people
#       - Nougat-Bar candies combination mostly liked by people
#       - Bar-chocolate,caramel,crispedricewafer candies combination mostly liked by people
# 8. Most of the __hard candies are not liked by people__, all hard candies are non bar candies have less winpercents
# 9. All pluribus candies are Non bar Candies
# 10. Predicted winpercent range for combination of each single flavor presence(1) and pricepercent range(0,0.5,1)
#       - chocolate(1)        - pricepercent(0,0.5,1)-> 50-65(winpercent)
#       - fruity(1)           - pricepercent(0,0.5,1)-> 39-52(winpercent)
#       - caramel(1)          - pricepercent(0,0.5,1)-> 43-62(winpercent)
#       - peanutyalmondy(1)   - pricepercent(0,0.5,1)-> 54-68(winpercent)
#       - nougat(1)           - pricepercent(0,0.5,1)-> 50-68(winpercent)
#       - crispedricewafer(1) - pricepercent(0,0.5,1)-> 58-72(winpercent)
#       - hard(1)             - pricepercent(0,0.5,1)-> 34-51(winpercent)
#       - bar(1)              - pricepercent(0,0.5,1)-> 55-64(winpercent)
#       - pluribus(1)         - pricepercent(0,0.5,1)-> 39-56(winpercent)
#
# Hence, mostly correlated features do not fetch for Linear Regression Model, we drop those features in Feature selection like __caramel,bar,hard,pluribus,crispedricewafer__ and then run model which on evaluation gives low RMSE value of __10.566__ , thus now our model is ready for predictions
